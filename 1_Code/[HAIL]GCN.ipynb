# %% [markdown]
# # 0. Package Install
#
#
# ---
#
# 주요 패키지
#
#
#
# 1.   ```Torch_geometric```
# 2.   ```Mendeleev```
# 3.   ```RDKit```
#
# *숨겨진 셀들을 아래의 실행버튼을 통해서 보지 않고 수행될 수 있도록 해주세요*

# %%
# Out:
#   File "<ipython-input-7-578a414ce986>", line 8
#     pip._vendor.packaging.version.InvalidVersion: Invalid version: 'latest+cu102'
#                                                                 ^
# SyntaxError: invalid syntax

# %%
# Install required packages.
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install -q torch-geometric
# !pip install mendeleev

# Helper function for visualization.
# %matplotlib inline
import torch
import networkx as nx
import matplotlib.pyplot as plt


def visualize(h, color, epoch=None, loss=None):
    plt.figure(figsize=(7,7))
    plt.xticks([])
    plt.yticks([])

    if torch.is_tensor(h):
        h = h.detach().cpu().numpy()
        plt.scatter(h[:, 0], h[:, 1], s=140, c=color, cmap="Set2")
        if epoch is not None and loss is not None:
            plt.xlabel(f'Epoch: {epoch}, Loss: {loss.item():.4f}', fontsize=16)
    else:
        nx.draw_networkx(G, pos=nx.spring_layout(G, seed=42), with_labels=False,
                         node_color=color, cmap="Set2")
    plt.show()
# Out:
# Collecting mendeleev
#   Downloading https://files.pythonhosted.org/packages/f0/75/5863bb298aa1390cb9ecb0548a62b8213ef085273f9d3c73e513b9c36214/mendeleev-0.6.1.tar.gz (193kB)
#      |████████████████████████████████| 194kB 18.8MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mendeleev) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from mendeleev) (1.1.5)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from mendeleev) (1.3.23)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Collecting pyfiglet
#   Downloading https://files.pythonhosted.org/packages/33/07/fcfdd7a2872f5b348953de35acce1544dab0c1e8368dca54279b1cde5c15/pyfiglet-0.8.post1-py2.py3-none-any.whl (865kB)
#      |████████████████████████████████| 870kB 49.0MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->mendeleev) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->mendeleev) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->mendeleev) (1.15.0)
# Building wheels for collected packages: mendeleev
#   Building wheel for mendeleev (setup.py) ... done
#   Created wheel for mendeleev: filename=mendeleev-0.6.1-py2.py3-none-any.whl size=174964 sha256=d84b6e4dd02529fb8a1eda939ad0f5e3c3e4c20c20a97e41ceebb3c80abdbaf1
#   Stored in directory: /root/.cache/pip/wheels/fb/28/5d/95e69a718b35dd00169889b0139a692f6c265d399cab3aa097
# Successfully built mendeleev
# Installing collected packages: colorama, pyfiglet, mendeleev
# Successfully installed colorama-0.4.4 mendeleev-0.6.1 pyfiglet-0.8.post1

# %%
import sys
import os
import requests
import subprocess
import shutil
from logging import getLogger, StreamHandler, INFO


logger = getLogger(__name__)
logger.addHandler(StreamHandler())
logger.setLevel(INFO)


def install(
        chunk_size=4096,
        file_name="Miniconda3-latest-Linux-x86_64.sh",
        url_base="https://repo.continuum.io/miniconda/",
        conda_path=os.path.expanduser(os.path.join("~", "miniconda")),
        rdkit_version=None,
        add_python_path=True,
        force=False):
    """install rdkit from miniconda
    ```
    import rdkit_installer
    rdkit_installer.install()
    ```
    """

    python_path = os.path.join(
        conda_path,
        "lib",
        "python{0}.{1}".format(*sys.version_info),
        "site-packages",
    )

    if add_python_path and python_path not in sys.path:
        logger.info("add {} to PYTHONPATH".format(python_path))
        sys.path.append(python_path)

    if os.path.isdir(os.path.join(python_path, "rdkit")):
        logger.info("rdkit is already installed")
        if not force:
            return

        logger.info("force re-install")

    url = url_base + file_name
    python_version = "{0}.{1}.{2}".format(*sys.version_info)

    logger.info("python version: {}".format(python_version))

    if os.path.isdir(conda_path):
        logger.warning("remove current miniconda")
        shutil.rmtree(conda_path)
    elif os.path.isfile(conda_path):
        logger.warning("remove {}".format(conda_path))
        os.remove(conda_path)

    logger.info('fetching installer from {}'.format(url))
    res = requests.get(url, stream=True)
    res.raise_for_status()
    with open(file_name, 'wb') as f:
        for chunk in res.iter_content(chunk_size):
            f.write(chunk)
    logger.info('done')

    logger.info('installing miniconda to {}'.format(conda_path))
    subprocess.check_call(["bash", file_name, "-b", "-p", conda_path])
    logger.info('done')

    logger.info("installing rdkit")
    subprocess.check_call([
        os.path.join(conda_path, "bin", "conda"),
        "install",
        "--yes",
        "-c", "rdkit",
        "python=={}".format(python_version),
        "rdkit" if rdkit_version is None else "rdkit=={}".format(rdkit_version)])
    logger.info("done")

    import rdkit
    logger.info("rdkit-{} installation finished!".format(rdkit.__version__))


if __name__ == "__main__":
  install()
# Out:
# add /root/miniconda/lib/python3.7/site-packages to PYTHONPATH
# python version: 3.7.10
# fetching installer from https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# done
# installing miniconda to /root/miniconda
# done
# installing rdkit
# done
# rdkit-2020.09.1 installation finished!

# %%
import numpy as np
import pandas as pd
import random

from sklearn.metrics import r2_score
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


from torch_geometric.data import Data
from torch_geometric.data import DataLoader
# from torch.utils.data import Dataset
# from torch.utils.data import DataLoader

from tqdm import tqdm

from mendeleev import get_table
from rdkit import Chem
from rdkit.Chem.Descriptors import ExactMolWt
from rdkit.Chem import Descriptors as desc
from rdkit.Chem import Crippen
from rdkit.Chem import Lipinski
from rdkit.Chem import AllChem
from rdkit.Chem import MolSurf

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric.nn as geonn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-454982c5b620> in <module>()
#      16 from tqdm import tqdm
#      17
# ---> 18 from mendeleev import get_table
#      19 from rdkit import Chem
#      20 from rdkit.Chem.Descriptors import ExactMolWt
#
# ModuleNotFoundError: No module named 'mendeleev'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # 1. Load DataSet & preprocessing
#
#
# ---
#
# 사용할 데이터를 불러오고, 학습에 사용할 DataSet으로 구성

# %%
# Load node Feature Table 
def get_elem_feats():
    # 기존 Preprocessing 을 수행하지 않은 데이터를 그대로 사용하던 코드 
    # tb_atom_feats = get_table('elements')
    # elem_feats = numpy.nan_to_num(numpy.array(tb_atom_feats[elem_feat_names]))

    tb_atom_feats = pd.read_excel("/content/drive/MyDrive/0_한동생활/2020-2.5 겨울방학/2_GNN/data/LOHC_MLproject_POSTECH/final_mendel.xlsx")
    elem_feats = np.array(tb_atom_feats[elem_feat_names])
    return elem_feats

# Load smiles Data 
def load_dataset(path_user_dataset):
    elem_feats = get_elem_feats()
    list_mols = np.zeros((1,2))
    id_target = np.array(pd.read_excel(path_user_dataset))

    for i in tqdm(range(0, id_target.shape[0])):
        mol = smiles_to_mol_graph(elem_feats, id_target[i, 0], idx=i, target=id_target[i, 1])

        if mol is not None:
          sample = np.array([id_target[i, 0], mol])
          list_mols = np.append(list_mols,
                                np.expand_dims(sample, axis=0),
                                axis=0)

    return list_mols[1:]

# Convert smiles to torch embedding molecular features
def smiles_to_mol_graph(elem_feats, smiles, idx, target):
    try:
        mol = Chem.MolFromSmiles(smiles)
        adj_mat = Chem.GetAdjacencyMatrix(mol)
        # adding Identity Matrix 
        # adj_mat = adj_mat + numpy.eye(len(adj_mat)) 
        atom_feats = list()
        bonds = list()

        for atom in mol.GetAtoms():
            atom_feats.append(elem_feats[atom.GetAtomicNum() - 1, :])

        for i in range(0, mol.GetNumAtoms()):
            for j in range(0, mol.GetNumAtoms()):
                if adj_mat[i, j] == 1:
                    bonds.append([i, j])

        if len(bonds) == 0:
            return None

        atom_feats = torch.tensor(atom_feats, dtype=torch.float)
        bonds = torch.tensor(bonds, dtype=torch.long).t().contiguous()
        y = torch.tensor(target, dtype=torch.float).view(1, 1)
        # for eGCN 
        MW = torch.tensor(ExactMolWt(mol)).view(1, 1)
        LOGP = torch.tensor(Crippen.MolLogP(mol)).view(1, 1)
        HBA = torch.tensor(Lipinski.NumHAcceptors(mol)).view(1, 1)
        HBD = torch.tensor(Lipinski.NumHDonors(mol)).view(1, 1)
        rotable = torch.tensor(Lipinski.NumRotatableBonds(mol)).view(1, 1)
        amide = torch.tensor(AllChem.CalcNumAmideBonds(mol)).view(1, 1)
        bridge = torch.tensor(AllChem.CalcNumBridgeheadAtoms(mol)).view(1, 1)
        heteroA = torch.tensor(Lipinski.NumHeteroatoms(mol)).view(1, 1)
        heavy = torch.tensor(Lipinski.HeavyAtomCount(mol)).view(1, 1)
        spiro = torch.tensor(AllChem.CalcNumSpiroAtoms(mol)).view(1, 1)
        FCSP3 = torch.tensor(AllChem.CalcFractionCSP3(mol)).view(1, 1)
        ring = torch.tensor(Lipinski.RingCount(mol)).view(1, 1)
        Aliphatic = torch.tensor(AllChem.CalcNumAliphaticRings(mol)).view(1, 1)
        aromatic = torch.tensor(AllChem.CalcNumAromaticRings(mol)).view(1, 1)
        saturated = torch.tensor(AllChem.CalcNumSaturatedRings(mol)).view(1, 1)
        heteroR = torch.tensor(AllChem.CalcNumHeterocycles(mol)).view(1, 1)
        TPSA = torch.tensor(MolSurf.TPSA(mol)).view(1, 1)
        valence = torch.tensor(desc.NumValenceElectrons(mol)).view(1, 1)
        mr = torch.tensor(Crippen.MolMR(mol)).view(1, 1)

        return Data(x=atom_feats, y=y, edge_index=bonds, idx=idx,
                    MW=MW, LOGP=LOGP, HBA=HBA, HBD=HBD, rotable=rotable, amide=amide, bridge=bridge, heteroA=heteroA, heavy=heavy, spiro=spiro, FCSP3=FCSP3, ring=ring, Aliphatic=Aliphatic, aromatic=aromatic, saturated=saturated, heteroR=heteroR, TPSA=TPSA, valence=valence, mr=mr)
    except:
        return

# %%
# Node(Atomic) Features로 사용할 columns 지정
elem_feat_names = ['atomic_weight', 'atomic_radius', 'atomic_volume', 'dipole_polarizability',
                   'fusion_heat', 'thermal_conductivity', 'vdw_radius', 'en_pauling',
                    'boiling_point','electron_affinity','en_allen','en_ghosh']
n_atom_feats = len(elem_feat_names)

# %%
# Load dataset
DataPath = "/content/drive/MyDrive/0_한동생활/2020-2.5 겨울방학/2_GNN/data/LOHC_MLproject_POSTECH/Dehydrogenation3.xlsx"

print('Load molecular structures...')
dataSet = load_dataset(DataPath)
# Out:
# Load molecular structures...
#   0%|          | 0/1465 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# 100%|██████████| 1465/1465 [00:04<00:00, 361.69it/s]

# %% [markdown]
# # 2. Train, Validate and Test
#
#
# ---
#
# 학습에 사용될 함수 정의

# %%
def train(model, optimizer, data_loader, criterion):
    model.train()
    train_loss = 0

    for i, (batch) in enumerate(data_loader):
        
        pred = model(batch.to(DEVICE))
        loss = criterion(batch.y, pred)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    return train_loss / len(data_loader)

def validate(model, data_loader, criterion):
  model.eval()
  val_loss =0
  
  with torch.no_grad():
    for i, (batch) in enumerate(data_loader):
        preds = model(batch.to(DEVICE))
        loss = criterion(preds, batch.y)
        val_loss += loss.item()

    val_loss = val_loss / len(data_loader)
  
  return val_loss

def test(model, data_loader):
    model.eval()
    list_preds = list()
    
    with torch.no_grad():
        for batch in data_loader:
            preds = model(batch.to(DEVICE))
            list_preds.append(preds)

    return torch.cat(list_preds, dim=0).cpu().numpy()

# %% [markdown]
# # 3. Model Construction
#
#
# ---
#
# 학습에 사용할 모델의 구조 설계

# %%
class EGCN(nn.Module):
    # extended graph convolutional network
    def __init__(self, args):
        super(EGCN, self).__init__()
        self.input_dim = args.input_dim
        self.hidden_dim = args.hidden_dim
        self.out_dim = args.out_dim
        
        # self.Norm = "Layer"
        # self.sc = "gated"
        # self.attention = False
        self.drop_p = args.drop_p

        self.gc1 = geonn.GCNConv(self.input_dim, self.hidden_dim)
        self.norm1 = geonn.LayerNorm(self.hidden_dim)

        self.gc2 = geonn.GCNConv(self.hidden_dim, self.hidden_dim)
        self.norm2 = geonn.LayerNorm(self.hidden_dim)

        self.gc3 = geonn.GCNConv(self.hidden_dim, self.hidden_dim)
        self.norm3 = geonn.LayerNorm(self.hidden_dim)

        self.fc1 = nn.Linear(self.hidden_dim + 19, self.hidden_dim*2)
        self.drop1 = nn.Dropout(p= self.drop_p)

        self.fc2 = nn.Linear(self.hidden_dim*2, self.hidden_dim*2)
        self.drop2 = nn.Dropout(p= self.drop_p)

        self.fc3 = nn.Linear(self.hidden_dim*2, self.out_dim)

    def forward(self, g):
        # Conv Layer 1
        h1 = self.gc1(g.x, g.edge_index)
        h1 = self.norm1(h1)
        h1 = F.relu(h1)

        # Conv Layer 2
        h2 = self.gc2(h1, g.edge_index)
        h2 = self.norm2(h2)
        h2 = F.relu(h2)

        # Conv Layer 3
        h3 = self.gc3(h2, g.edge_index)
        h3 = self.norm3(h3)
        h3 = F.relu(h3)

        # Read Out Layer 
        hg = geonn.global_mean_pool(h3, g.batch)

        # eGCN, concat Layer
        hg = torch.cat([hg, g.MW, g.LOGP, g.HBA, g.HBD, g.rotable, g.amide, g.bridge, g.heteroA, g.heavy, g.spiro, g.FCSP3, g.ring, g.Aliphatic, g.aromatic, g.saturated, g.heteroR, g.TPSA, g.valence,g.mr],
                       dim=1)
        
        # FCN Layer 1 
        hg = self.fc1(hg)
        if self.drop_p :
         hg = self.drop1(hg)
        hg = F.relu(hg)

        # FCN Layer 2 
        hg = self.fc2(hg)
        if self.drop_p :
          hg = self.drop2(hg)
        hg = F.relu(hg)

        # FCN Layer 3 
        out = self.fc3(hg)

        return out

# %%
class GatedSkipConnection(nn.Module):
    
    def __init__(self, in_dim, out_dim):
        super(GatedSkipConnection, self).__init__()
        
        self.in_dim = in_dim
        self.out_dim = out_dim
        
        self.linear = nn.Linear(in_dim, out_dim, bias=False)
        self.linear_coef_in = nn.Linear(out_dim, out_dim)
        self.linear_coef_out = nn.Linear(out_dim, out_dim)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, in_x, out_x):
        if (self.in_dim != self.out_dim):
            in_x = self.linear(in_x)
        z = self.gate_coefficient(in_x, out_x)
        out = torch.mul(z, out_x) + torch.mul(1.0-z, in_x)
        return out
            
    def gate_coefficient(self, in_x, out_x):
        x1 = self.linear_coef_in(in_x)
        x2 = self.linear_coef_out(out_x)
        return self.sigmoid(x1+x2)
        
class SkipConnection(nn.Module):
    
    def __init__(self, in_dim, out_dim):
        super(SkipConnection, self).__init__()
        
        self.in_dim = in_dim
        self.out_dim = out_dim
        
        self.linear = nn.Linear(in_dim, out_dim, bias=False)
        
    def forward(self, in_x, out_x):
        if (self.in_dim != self.out_dim):
            in_x = self.linear(in_x)
        out = in_x + out_x
        return out

# %% [markdown]
# # 4. Experiment
#
#
# ---
# Set up Hyperparameter, learning param.

# %%
import argparse

paser = argparse.ArgumentParser()
args = paser.parse_args("")

# %%
# Setting

# 1. Model 
args.input_dim = n_atom_feats
args.hidden_dim = 256
args.out_dim = 1 

# args.Norm = "Layer"
# args.sc = "gated"
# args.attention = False
args.drop_p = 0.5

# 2. learing 
args.batch_size = 32
args.init_lr = 0.001
args.l2_coeff = 0.0
args.n_epochs = 30000

# %%
convert = str(args)
print(convert)
# Out:
# Namespace(batch_size=32, drop_p=0.5, hidden_dim=256, init_lr=0.001, input_dim=12, l2_coeff=0.0, n_epochs=30000, out_dim=1)

# %%
args.MODEL_NAME = 'eGCN' 
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
args.DEVICE = DEVICE
print("MODEL_NAME = {}, DEVICE = {}".format(args.MODEL_NAME,args.DEVICE))

# model = EGCN(input_dim=input_dim, hidden_dim=hidden_dim, out_dim=out_dim).to(DEVICE)
model = EGCN(args).to(DEVICE)
# Out:
# MODEL_NAME = eGCN, DEVICE = cuda

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=args.init_lr, weight_decay=args.l2_coeff)
criterion = torch.nn.L1Loss()

# %%
# Generate training and test datasets

# train : validation : test = 8 : 1 : 1 
train_data, unseen_data = train_test_split(dataSet,test_size=0.2, random_state=400)
validate_data, test_data = train_test_split(unseen_data, test_size=0.5, random_state=400)

train_smiles = train_data[:, 0]
validate_smiles = validate_data[:, 0]
test_smiles = test_data[:, 0]

train_loader = DataLoader(train_data[:, 1], batch_size=args.batch_size, shuffle=True, drop_last=True)
validate_loader = DataLoader(validate_data[:, 1], batch_size=100, drop_last=False)
test_loader = DataLoader(test_data[:, 1], batch_size=100, drop_last=False)

train_targets = np.array([x.y.item() for x in train_data[:,1]]).reshape(-1, 1)
validate_targets = np.array([x.y.item() for x in validate_data[:,1]]).reshape(-1, 1)
test_targets = np.array([x.y.item() for x in test_data[:,1]]).reshape(-1, 1)

# %%
# utility function to measure time
import time
import math

all_seq = np.empty((1,4), dtype=float)
train_losses = []
vali_losses = [] 

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %%
# Train graph neural network (GNN)
print('Train the GNN-based predictor...')
start = time.time()
for i in range(0, args.n_epochs):
    train_loss = train(model, optimizer, train_loader, criterion)
    vali_loss = validate(model, validate_loader, criterion)
    print('Time : {:10s} | Epoch [{}/{}]\tTrain loss: {:.4f}\t Vali loss: {:0.4f}'.format(timeSince(start),i + 1, args.n_epochs, train_loss, vali_loss))
    

    # Test the trained GNN

    train_losses.append(train_loss)
    vali_losses.append(vali_loss)
    if (i+1) % 25 == 0 : 
      # model.eval()
      preds = test(model, test_loader)
      test_mae = np.mean(np.abs(test_targets - preds))
      test_std = np.std(test_targets - preds)

      r2 = r2_score(test_targets, preds)
      print("------------------Train Test------------------")
      print("Now Epoch [{}/{}]".format(i+1, args.n_epochs))
      print('Test MAE: {:.4f}\t Test Std.: {:.4f}\tTest R2 score: {:.4f}'.format(test_mae,test_std, r2))
      print("----------------------------------------------")
      item = np.array((i+1, test_mae, test_std, r2))
      all_seq = np.append(all_seq, np.expand_dims(item, axis=0), axis=0)
# Out:
# Train the GNN-based predictor...
# Time : 0m 0s      | Epoch [1/30000]	Train loss: 9.1615	 Vali loss: 10.2461
# Time : 0m 1s      | Epoch [2/30000]	Train loss: 10.0080	 Vali loss: 5.6882
# Time : 0m 1s      | Epoch [3/30000]	Train loss: 9.3177	 Vali loss: 6.5639
# Time : 0m 2s      | Epoch [4/30000]	Train loss: 8.9887	 Vali loss: 5.7476
# Time : 0m 2s      | Epoch [5/30000]	Train loss: 9.0662	 Vali loss: 6.0994
# Time : 0m 3s      | Epoch [6/30000]	Train loss: 10.3361	 Vali loss: 5.6888
# Time : 0m 4s      | Epoch [7/30000]	Train loss: 9.0791	 Vali loss: 7.0836
# Time : 0m 4s      | Epoch [8/30000]	Train loss: 9.1710	 Vali loss: 6.6093
# Time : 0m 5s      | Epoch [9/30000]	Train loss: 9.1670	 Vali loss: 5.9516
# Time : 0m 5s      | Epoch [10/30000]	Train loss: 9.2020	 Vali loss: 6.0076
# Time : 0m 6s      | Epoch [11/30000]	Train loss: 9.1813	 Vali loss: 9.6427
# Time : 0m 6s      | Epoch [12/30000]	Train loss: 9.6662	 Vali loss: 5.8077
# Time : 0m 7s      | Epoch [13/30000]	Train loss: 8.9944	 Vali loss: 6.3937
# Time : 0m 8s      | Epoch [14/30000]	Train loss: 9.5503	 Vali loss: 9.9048
# Time : 0m 8s      | Epoch [15/30000]	Train loss: 9.7005	 Vali loss: 7.1864
# Time : 0m 9s      | Epoch [16/30000]	Train loss: 9.1550	 Vali loss: 5.6148
# Time : 0m 9s      | Epoch [17/30000]	Train loss: 9.4534	 Vali loss: 7.9410
# Time : 0m 10s     | Epoch [18/30000]	Train loss: 9.1687	 Vali loss: 5.8975
# Time : 0m 10s     | Epoch [19/30000]	Train loss: 9.1733	 Vali loss: 5.4324
# Time : 0m 11s     | Epoch [20/30000]	Train loss: 8.9467	 Vali loss: 6.2271
# Time : 0m 12s     | Epoch [21/30000]	Train loss: 9.0068	 Vali loss: 5.4828
# Time : 0m 12s     | Epoch [22/30000]	Train loss: 9.1382	 Vali loss: 6.1769
# Time : 0m 13s     | Epoch [23/30000]	Train loss: 9.1807	 Vali loss: 5.7770
# Time : 0m 13s     | Epoch [24/30000]	Train loss: 9.0402	 Vali loss: 5.4613
# Time : 0m 14s     | Epoch [25/30000]	Train loss: 9.3437	 Vali loss: 6.5453
# ------------------Train Test------------------
# Now Epoch [25/30000]
# Test MAE: 6.4441	 Test Std.: 9.3085	Test R2 score: 0.7465
# ----------------------------------------------
# Time : 0m 15s     | Epoch [26/30000]	Train loss: 8.8626	 Vali loss: 6.8059
# Time : 0m 15s     | Epoch [27/30000]	Train loss: 9.0453	 Vali loss: 7.1932
# Time : 0m 16s     | Epoch [28/30000]	Train loss: 9.2276	 Vali loss: 8.7121
# Time : 0m 16s     | Epoch [29/30000]	Train loss: 9.5859	 Vali loss: 8.0065
# Time : 0m 17s     | Epoch [30/30000]	Train loss: 9.3704	 Vali loss: 5.9194
# Time : 0m 17s     | Epoch [31/30000]	Train loss: 8.8467	 Vali loss: 6.7037
# Time : 0m 18s     | Epoch [32/30000]	Train loss: 8.8680	 Vali loss: 6.7451
# Time : 0m 19s     | Epoch [33/30000]	Train loss: 8.6456	 Vali loss: 6.2637
# Time : 0m 19s     | Epoch [34/30000]	Train loss: 8.9201	 Vali loss: 6.5236
# Time : 0m 20s     | Epoch [35/30000]	Train loss: 8.8468	 Vali loss: 9.5046
# Time : 0m 20s     | Epoch [36/30000]	Train loss: 9.5377	 Vali loss: 5.4665
# Time : 0m 21s     | Epoch [37/30000]	Train loss: 8.9899	 Vali loss: 6.3898
# Time : 0m 21s     | Epoch [38/30000]	Train loss: 9.0248	 Vali loss: 5.7369
# Time : 0m 22s     | Epoch [39/30000]	Train loss: 8.6904	 Vali loss: 5.6690
# Time : 0m 23s     | Epoch [40/30000]	Train loss: 8.8887	 Vali loss: 9.3085
# Time : 0m 23s     | Epoch [41/30000]	Train loss: 8.5629	 Vali loss: 5.3360
# Time : 0m 24s     | Epoch [42/30000]	Train loss: 8.8814	 Vali loss: 6.0138
# Time : 0m 24s     | Epoch [43/30000]	Train loss: 9.1606	 Vali loss: 5.1731
# Time : 0m 25s     | Epoch [44/30000]	Train loss: 8.7156	 Vali loss: 7.5077
# Time : 0m 25s     | Epoch [45/30000]	Train loss: 8.4763	 Vali loss: 6.1491
# Time : 0m 26s     | Epoch [46/30000]	Train loss: 8.7223	 Vali loss: 6.5497
# Time : 0m 27s     | Epoch [47/30000]	Train loss: 8.7637	 Vali loss: 7.5160
# Time : 0m 27s     | Epoch [48/30000]	Train loss: 9.1760	 Vali loss: 9.3620
# Time : 0m 28s     | Epoch [49/30000]	Train loss: 8.9971	 Vali loss: 6.0926
# Time : 0m 28s     | Epoch [50/30000]	Train loss: 9.0842	 Vali loss: 6.0288
# ------------------Train Test------------------
# Now Epoch [50/30000]
# Test MAE: 5.6540	 Test Std.: 8.5054	Test R2 score: 0.7910
# ----------------------------------------------
# Time : 0m 29s     | Epoch [51/30000]	Train loss: 8.8878	 Vali loss: 6.7735
# Time : 0m 29s     | Epoch [52/30000]	Train loss: 8.9311	 Vali loss: 6.2261
# Time : 0m 30s     | Epoch [53/30000]	Train loss: 8.7099	 Vali loss: 8.3240
# Time : 0m 31s     | Epoch [54/30000]	Train loss: 8.8098	 Vali loss: 8.9189
# Time : 0m 31s     | Epoch [55/30000]	Train loss: 9.0290	 Vali loss: 5.4299
# Time : 0m 32s     | Epoch [56/30000]	Train loss: 8.8546	 Vali loss: 5.4151
# Time : 0m 32s     | Epoch [57/30000]	Train loss: 8.9486	 Vali loss: 6.0290
# Time : 0m 33s     | Epoch [58/30000]	Train loss: 9.0220	 Vali loss: 6.4672
# Time : 0m 33s     | Epoch [59/30000]	Train loss: 9.5374	 Vali loss: 8.5827
# Time : 0m 34s     | Epoch [60/30000]	Train loss: 9.9296	 Vali loss: 6.1099
# Time : 0m 35s     | Epoch [61/30000]	Train loss: 9.9237	 Vali loss: 6.0707
# Time : 0m 35s     | Epoch [62/30000]	Train loss: 8.6456	 Vali loss: 5.5117
# Time : 0m 36s     | Epoch [63/30000]	Train loss: 9.0262	 Vali loss: 6.5480
# Time : 0m 36s     | Epoch [64/30000]	Train loss: 8.6642	 Vali loss: 8.2597
# Time : 0m 37s     | Epoch [65/30000]	Train loss: 8.7149	 Vali loss: 5.9174
# Time : 0m 37s     | Epoch [66/30000]	Train loss: 9.0941	 Vali loss: 6.3519
# Time : 0m 38s     | Epoch [67/30000]	Train loss: 8.7856	 Vali loss: 5.1312
# Time : 0m 39s     | Epoch [68/30000]	Train loss: 8.8586	 Vali loss: 6.0438
# Time : 0m 39s     | Epoch [69/30000]	Train loss: 8.8258	 Vali loss: 6.0012
# Time : 0m 40s     | Epoch [70/30000]	Train loss: 8.3636	 Vali loss: 6.3328
# Time : 0m 40s     | Epoch [71/30000]	Train loss: 9.0993	 Vali loss: 5.7170
# Time : 0m 41s     | Epoch [72/30000]	Train loss: 8.9197	 Vali loss: 5.4921
# Time : 0m 42s     | Epoch [73/30000]	Train loss: 8.5582	 Vali loss: 5.3592
# Time : 0m 42s     | Epoch [74/30000]	Train loss: 8.8110	 Vali loss: 5.6726
# Time : 0m 43s     | Epoch [75/30000]	Train loss: 9.1496	 Vali loss: 8.6809
# ------------------Train Test------------------
# Now Epoch [75/30000]
# Test MAE: 8.0219	 Test Std.: 8.6774	Test R2 score: 0.7159
# ----------------------------------------------
# Time : 0m 43s     | Epoch [76/30000]	Train loss: 8.6994	 Vali loss: 6.1742
# Time : 0m 44s     | Epoch [77/30000]	Train loss: 8.8309	 Vali loss: 6.4074
# Time : 0m 44s     | Epoch [78/30000]	Train loss: 9.2868	 Vali loss: 5.9025
# Time : 0m 45s     | Epoch [79/30000]	Train loss: 9.0387	 Vali loss: 6.3869
# Time : 0m 46s     | Epoch [80/30000]	Train loss: 8.6695	 Vali loss: 5.9093
# Time : 0m 46s     | Epoch [81/30000]	Train loss: 8.6611	 Vali loss: 6.2415
# Time : 0m 47s     | Epoch [82/30000]	Train loss: 8.6215	 Vali loss: 8.3367
# Time : 0m 47s     | Epoch [83/30000]	Train loss: 8.8308	 Vali loss: 5.6878
# Time : 0m 48s     | Epoch [84/30000]	Train loss: 8.8054	 Vali loss: 6.5195
# Time : 0m 48s     | Epoch [85/30000]	Train loss: 8.3194	 Vali loss: 6.4500
# Time : 0m 49s     | Epoch [86/30000]	Train loss: 8.5446	 Vali loss: 5.2136
# Time : 0m 50s     | Epoch [87/30000]	Train loss: 9.3685	 Vali loss: 5.2938
# Time : 0m 50s     | Epoch [88/30000]	Train loss: 8.7818	 Vali loss: 7.9584
# Time : 0m 51s     | Epoch [89/30000]	Train loss: 8.6931	 Vali loss: 5.7733
# Time : 0m 51s     | Epoch [90/30000]	Train loss: 8.6907	 Vali loss: 6.1670
# Time : 0m 52s     | Epoch [91/30000]	Train loss: 8.8216	 Vali loss: 6.5943
# Time : 0m 52s     | Epoch [92/30000]	Train loss: 8.9421	 Vali loss: 5.5481
# Time : 0m 53s     | Epoch [93/30000]	Train loss: 8.5062	 Vali loss: 6.2515
# Time : 0m 54s     | Epoch [94/30000]	Train loss: 8.6094	 Vali loss: 5.9578
# Time : 0m 54s     | Epoch [95/30000]	Train loss: 8.5190	 Vali loss: 5.8828
# Time : 0m 55s     | Epoch [96/30000]	Train loss: 9.0395	 Vali loss: 8.8642
# Time : 0m 55s     | Epoch [97/30000]	Train loss: 8.7596	 Vali loss: 7.0779
# Time : 0m 56s     | Epoch [98/30000]	Train loss: 8.7215	 Vali loss: 6.0966
# Time : 0m 57s     | Epoch [99/30000]	Train loss: 8.8033	 Vali loss: 5.7836
# Time : 0m 57s     | Epoch [100/30000]	Train loss: 8.1671	 Vali loss: 5.6366
# ------------------Train Test------------------
# Now Epoch [100/30000]
# Test MAE: 5.6131	 Test Std.: 8.6520	Test R2 score: 0.7825
# ----------------------------------------------
# Time : 0m 58s     | Epoch [101/30000]	Train loss: 8.4310	 Vali loss: 5.3509
# Time : 0m 58s     | Epoch [102/30000]	Train loss: 8.6752	 Vali loss: 7.6157
# Time : 0m 59s     | Epoch [103/30000]	Train loss: 8.9405	 Vali loss: 7.5904
# Time : 0m 59s     | Epoch [104/30000]	Train loss: 8.7176	 Vali loss: 5.7822
# Time : 1m 0s      | Epoch [105/30000]	Train loss: 8.3253	 Vali loss: 6.5647
# Time : 1m 1s      | Epoch [106/30000]	Train loss: 8.6089	 Vali loss: 5.9135
# Time : 1m 1s      | Epoch [107/30000]	Train loss: 8.4367	 Vali loss: 5.4244
# Time : 1m 2s      | Epoch [108/30000]	Train loss: 8.4664	 Vali loss: 5.6283
# Time : 1m 2s      | Epoch [109/30000]	Train loss: 9.3219	 Vali loss: 7.6102
# Time : 1m 3s      | Epoch [110/30000]	Train loss: 8.7334	 Vali loss: 6.3988
# Time : 1m 3s      | Epoch [111/30000]	Train loss: 8.6698	 Vali loss: 6.7896
# Time : 1m 4s      | Epoch [112/30000]	Train loss: 8.6200	 Vali loss: 5.8892
# Time : 1m 5s      | Epoch [113/30000]	Train loss: 9.1268	 Vali loss: 9.8900
# Time : 1m 5s      | Epoch [114/30000]	Train loss: 9.2057	 Vali loss: 5.7652
# Time : 1m 6s      | Epoch [115/30000]	Train loss: 8.7252	 Vali loss: 5.9454
# Time : 1m 6s      | Epoch [116/30000]	Train loss: 8.8684	 Vali loss: 6.5566
# Time : 1m 7s      | Epoch [117/30000]	Train loss: 8.9537	 Vali loss: 7.9110
# Time : 1m 7s      | Epoch [118/30000]	Train loss: 9.1871	 Vali loss: 5.6987
# Time : 1m 8s      | Epoch [119/30000]	Train loss: 8.6127	 Vali loss: 6.1041
# Time : 1m 9s      | Epoch [120/30000]	Train loss: 8.7227	 Vali loss: 6.3982
# Time : 1m 9s      | Epoch [121/30000]	Train loss: 9.0812	 Vali loss: 10.2579
# Time : 1m 10s     | Epoch [122/30000]	Train loss: 9.0892	 Vali loss: 5.1704
# Time : 1m 10s     | Epoch [123/30000]	Train loss: 8.6124	 Vali loss: 6.6113
# Time : 1m 11s     | Epoch [124/30000]	Train loss: 8.6901	 Vali loss: 5.5388
# Time : 1m 11s     | Epoch [125/30000]	Train loss: 8.3336	 Vali loss: 6.1694
# ------------------Train Test------------------
# Now Epoch [125/30000]
# Test MAE: 6.1129	 Test Std.: 8.7092	Test R2 score: 0.7816
# ----------------------------------------------
# Time : 1m 12s     | Epoch [126/30000]	Train loss: 8.3621	 Vali loss: 6.2241
# Time : 1m 13s     | Epoch [127/30000]	Train loss: 8.3264	 Vali loss: 5.9672
# Time : 1m 13s     | Epoch [128/30000]	Train loss: 9.1039	 Vali loss: 6.5430
# Time : 1m 14s     | Epoch [129/30000]	Train loss: 8.7184	 Vali loss: 5.6256
# Time : 1m 14s     | Epoch [130/30000]	Train loss: 8.4406	 Vali loss: 5.5863
# Time : 1m 15s     | Epoch [131/30000]	Train loss: 8.4559	 Vali loss: 6.0398
# Time : 1m 16s     | Epoch [132/30000]	Train loss: 8.9355	 Vali loss: 5.1057
# Time : 1m 16s     | Epoch [133/30000]	Train loss: 8.3112	 Vali loss: 6.9677
# Time : 1m 17s     | Epoch [134/30000]	Train loss: 8.3404	 Vali loss: 5.3732
# Time : 1m 17s     | Epoch [135/30000]	Train loss: 9.3900	 Vali loss: 7.2649
# Time : 1m 18s     | Epoch [136/30000]	Train loss: 8.5370	 Vali loss: 7.8476
# Time : 1m 18s     | Epoch [137/30000]	Train loss: 8.3738	 Vali loss: 8.3726
# Time : 1m 19s     | Epoch [138/30000]	Train loss: 8.4642	 Vali loss: 6.3813
# Time : 1m 20s     | Epoch [139/30000]	Train loss: 8.9346	 Vali loss: 5.2838
# Time : 1m 20s     | Epoch [140/30000]	Train loss: 9.4497	 Vali loss: 7.4935
# Time : 1m 21s     | Epoch [141/30000]	Train loss: 8.7954	 Vali loss: 7.2203
# Time : 1m 21s     | Epoch [142/30000]	Train loss: 8.2095	 Vali loss: 8.0984
# Time : 1m 22s     | Epoch [143/30000]	Train loss: 9.2801	 Vali loss: 7.4113
# Time : 1m 22s     | Epoch [144/30000]	Train loss: 8.8867	 Vali loss: 5.9189
# Time : 1m 23s     | Epoch [145/30000]	Train loss: 8.8118	 Vali loss: 8.0596
# Time : 1m 24s     | Epoch [146/30000]	Train loss: 7.8653	 Vali loss: 5.6429
# Time : 1m 24s     | Epoch [147/30000]	Train loss: 8.3467	 Vali loss: 8.3966
# Time : 1m 25s     | Epoch [148/30000]	Train loss: 8.7396	 Vali loss: 5.3973
# Time : 1m 25s     | Epoch [149/30000]	Train loss: 8.6268	 Vali loss: 5.3081
# Time : 1m 26s     | Epoch [150/30000]	Train loss: 8.6513	 Vali loss: 6.1286
# ------------------Train Test------------------
# Now Epoch [150/30000]
# Test MAE: 5.6451	 Test Std.: 8.3409	Test R2 score: 0.8000
# ----------------------------------------------
# Time : 1m 26s     | Epoch [151/30000]	Train loss: 8.6556	 Vali loss: 6.9524
# Time : 1m 27s     | Epoch [152/30000]	Train loss: 8.1982	 Vali loss: 5.3057
# Time : 1m 28s     | Epoch [153/30000]	Train loss: 8.4769	 Vali loss: 11.2810
# Time : 1m 28s     | Epoch [154/30000]	Train loss: 9.0594	 Vali loss: 5.8931
# Time : 1m 29s     | Epoch [155/30000]	Train loss: 8.4768	 Vali loss: 7.3339
# Time : 1m 29s     | Epoch [156/30000]	Train loss: 8.6420	 Vali loss: 8.8901
# Time : 1m 30s     | Epoch [157/30000]	Train loss: 8.7805	 Vali loss: 5.2079
# Time : 1m 30s     | Epoch [158/30000]	Train loss: 8.6959	 Vali loss: 5.5233
# Time : 1m 31s     | Epoch [159/30000]	Train loss: 8.1761	 Vali loss: 6.0343
# Time : 1m 32s     | Epoch [160/30000]	Train loss: 8.0410	 Vali loss: 5.6355
# Time : 1m 32s     | Epoch [161/30000]	Train loss: 8.5813	 Vali loss: 5.8039
# Time : 1m 33s     | Epoch [162/30000]	Train loss: 8.8237	 Vali loss: 5.6854
# Time : 1m 33s     | Epoch [163/30000]	Train loss: 8.7219	 Vali loss: 5.4105
# Time : 1m 34s     | Epoch [164/30000]	Train loss: 8.6804	 Vali loss: 7.9069
# Time : 1m 34s     | Epoch [165/30000]	Train loss: 8.4258	 Vali loss: 8.9684
# Time : 1m 35s     | Epoch [166/30000]	Train loss: 8.2847	 Vali loss: 5.8243
# Time : 1m 36s     | Epoch [167/30000]	Train loss: 8.3643	 Vali loss: 8.5972
# Time : 1m 36s     | Epoch [168/30000]	Train loss: 8.7284	 Vali loss: 5.2172
# Time : 1m 37s     | Epoch [169/30000]	Train loss: 8.3550	 Vali loss: 5.7532
# Time : 1m 37s     | Epoch [170/30000]	Train loss: 8.7598	 Vali loss: 7.3462
# Time : 1m 38s     | Epoch [171/30000]	Train loss: 9.5900	 Vali loss: 5.3300
# Time : 1m 39s     | Epoch [172/30000]	Train loss: 8.9637	 Vali loss: 5.3508
# Time : 1m 39s     | Epoch [173/30000]	Train loss: 8.3505	 Vali loss: 6.6016
# Time : 1m 40s     | Epoch [174/30000]	Train loss: 8.7298	 Vali loss: 5.1471
# Time : 1m 40s     | Epoch [175/30000]	Train loss: 8.4504	 Vali loss: 5.3641
# ------------------Train Test------------------
# Now Epoch [175/30000]
# Test MAE: 6.6133	 Test Std.: 9.0898	Test R2 score: 0.7280
# ----------------------------------------------
# Time : 1m 41s     | Epoch [176/30000]	Train loss: 7.9944	 Vali loss: 5.4551
# Time : 1m 41s     | Epoch [177/30000]	Train loss: 8.5521	 Vali loss: 5.3068
# Time : 1m 42s     | Epoch [178/30000]	Train loss: 8.5512	 Vali loss: 9.4263
# Time : 1m 43s     | Epoch [179/30000]	Train loss: 8.9597	 Vali loss: 5.4141
# Time : 1m 43s     | Epoch [180/30000]	Train loss: 8.3658	 Vali loss: 5.6365
# Time : 1m 44s     | Epoch [181/30000]	Train loss: 9.2850	 Vali loss: 5.6618
# Time : 1m 44s     | Epoch [182/30000]	Train loss: 8.1450	 Vali loss: 5.5015
# Time : 1m 45s     | Epoch [183/30000]	Train loss: 8.3404	 Vali loss: 7.9517
# Time : 1m 46s     | Epoch [184/30000]	Train loss: 8.5441	 Vali loss: 7.9383
# Time : 1m 46s     | Epoch [185/30000]	Train loss: 9.4155	 Vali loss: 6.0525
# Time : 1m 47s     | Epoch [186/30000]	Train loss: 8.3558	 Vali loss: 5.4018
# Time : 1m 47s     | Epoch [187/30000]	Train loss: 8.3950	 Vali loss: 8.3131
# Time : 1m 48s     | Epoch [188/30000]	Train loss: 8.5912	 Vali loss: 4.9900
# Time : 1m 48s     | Epoch [189/30000]	Train loss: 8.1344	 Vali loss: 4.9297
# Time : 1m 49s     | Epoch [190/30000]	Train loss: 8.2711	 Vali loss: 6.8602
# Time : 1m 50s     | Epoch [191/30000]	Train loss: 8.0232	 Vali loss: 5.0987
# Time : 1m 50s     | Epoch [192/30000]	Train loss: 8.4814	 Vali loss: 6.2832
# Time : 1m 51s     | Epoch [193/30000]	Train loss: 8.5270	 Vali loss: 7.1784
# Time : 1m 51s     | Epoch [194/30000]	Train loss: 8.5741	 Vali loss: 5.1943
# Time : 1m 52s     | Epoch [195/30000]	Train loss: 8.5457	 Vali loss: 5.2127
# Time : 1m 52s     | Epoch [196/30000]	Train loss: 8.2457	 Vali loss: 5.8069
# Time : 1m 53s     | Epoch [197/30000]	Train loss: 8.3415	 Vali loss: 9.2914
# Time : 1m 54s     | Epoch [198/30000]	Train loss: 8.5267	 Vali loss: 5.5143
# Time : 1m 54s     | Epoch [199/30000]	Train loss: 8.5633	 Vali loss: 5.4497
# Time : 1m 55s     | Epoch [200/30000]	Train loss: 8.1544	 Vali loss: 7.4616
# ------------------Train Test------------------
# Now Epoch [200/30000]
# Test MAE: 6.3272	 Test Std.: 8.4328	Test R2 score: 0.7618
# ----------------------------------------------
# Time : 1m 55s     | Epoch [201/30000]	Train loss: 8.1659	 Vali loss: 6.5865
# Time : 1m 56s     | Epoch [202/30000]	Train loss: 8.2479	 Vali loss: 5.5499
# Time : 1m 57s     | Epoch [203/30000]	Train loss: 8.8743	 Vali loss: 5.3480
# Time : 1m 57s     | Epoch [204/30000]	Train loss: 8.6798	 Vali loss: 5.6572
# Time : 1m 58s     | Epoch [205/30000]	Train loss: 8.5805	 Vali loss: 5.2448
# Time : 1m 58s     | Epoch [206/30000]	Train loss: 8.3589	 Vali loss: 5.6219
# Time : 1m 59s     | Epoch [207/30000]	Train loss: 8.3914	 Vali loss: 5.8747
# Time : 1m 59s     | Epoch [208/30000]	Train loss: 8.6582	 Vali loss: 6.1521
# Time : 2m 0s      | Epoch [209/30000]	Train loss: 8.4537	 Vali loss: 6.0998
# Time : 2m 1s      | Epoch [210/30000]	Train loss: 8.5530	 Vali loss: 5.6530
# Time : 2m 1s      | Epoch [211/30000]	Train loss: 8.0508	 Vali loss: 5.4957
# Time : 2m 2s      | Epoch [212/30000]	Train loss: 8.6700	 Vali loss: 9.9562
# Time : 2m 2s      | Epoch [213/30000]	Train loss: 8.8941	 Vali loss: 5.7090
# Time : 2m 3s      | Epoch [214/30000]	Train loss: 8.4788	 Vali loss: 7.4988
# Time : 2m 3s      | Epoch [215/30000]	Train loss: 8.6097	 Vali loss: 5.1654
# Time : 2m 4s      | Epoch [216/30000]	Train loss: 8.5376	 Vali loss: 6.5840
# Time : 2m 5s      | Epoch [217/30000]	Train loss: 8.5145	 Vali loss: 5.2826
# Time : 2m 5s      | Epoch [218/30000]	Train loss: 8.5385	 Vali loss: 5.2080
# Time : 2m 6s      | Epoch [219/30000]	Train loss: 8.4864	 Vali loss: 8.5881
# Time : 2m 6s      | Epoch [220/30000]	Train loss: 8.5743	 Vali loss: 5.1042
# Time : 2m 7s      | Epoch [221/30000]	Train loss: 8.7759	 Vali loss: 6.2087
# Time : 2m 7s      | Epoch [222/30000]	Train loss: 8.8943	 Vali loss: 5.5840
# Time : 2m 8s      | Epoch [223/30000]	Train loss: 8.8246	 Vali loss: 6.0910
# Time : 2m 8s      | Epoch [224/30000]	Train loss: 8.3734	 Vali loss: 5.8822
# Time : 2m 9s      | Epoch [225/30000]	Train loss: 9.3059	 Vali loss: 6.7366
# ------------------Train Test------------------
# Now Epoch [225/30000]
# Test MAE: 8.3146	 Test Std.: 9.4738	Test R2 score: 0.6419
# ----------------------------------------------
# Time : 2m 10s     | Epoch [226/30000]	Train loss: 8.5966	 Vali loss: 5.2729
# Time : 2m 10s     | Epoch [227/30000]	Train loss: 8.1192	 Vali loss: 8.1063
# Time : 2m 11s     | Epoch [228/30000]	Train loss: 8.3624	 Vali loss: 6.9578
# Time : 2m 11s     | Epoch [229/30000]	Train loss: 8.4672	 Vali loss: 7.7277
# Time : 2m 12s     | Epoch [230/30000]	Train loss: 8.3556	 Vali loss: 6.4139
# Time : 2m 13s     | Epoch [231/30000]	Train loss: 8.6160	 Vali loss: 5.4918
# Time : 2m 13s     | Epoch [232/30000]	Train loss: 8.5480	 Vali loss: 5.7323
# Time : 2m 14s     | Epoch [233/30000]	Train loss: 7.8191	 Vali loss: 5.5675
# Time : 2m 14s     | Epoch [234/30000]	Train loss: 8.7926	 Vali loss: 6.7953
# Time : 2m 15s     | Epoch [235/30000]	Train loss: 8.5366	 Vali loss: 5.0009
# Time : 2m 15s     | Epoch [236/30000]	Train loss: 8.2780	 Vali loss: 6.0046
# Time : 2m 16s     | Epoch [237/30000]	Train loss: 8.5205	 Vali loss: 5.3279
# Time : 2m 17s     | Epoch [238/30000]	Train loss: 7.8329	 Vali loss: 5.1160
# Time : 2m 17s     | Epoch [239/30000]	Train loss: 8.6347	 Vali loss: 8.2423
# Time : 2m 18s     | Epoch [240/30000]	Train loss: 8.8397	 Vali loss: 7.5660
# Time : 2m 18s     | Epoch [241/30000]	Train loss: 8.7469	 Vali loss: 5.6656
# Time : 2m 19s     | Epoch [242/30000]	Train loss: 8.2828	 Vali loss: 6.0922
# Time : 2m 19s     | Epoch [243/30000]	Train loss: 9.0807	 Vali loss: 6.6006
# Time : 2m 20s     | Epoch [244/30000]	Train loss: 8.5615	 Vali loss: 6.0649
# Time : 2m 21s     | Epoch [245/30000]	Train loss: 8.3663	 Vali loss: 5.2064
# Time : 2m 21s     | Epoch [246/30000]	Train loss: 8.3287	 Vali loss: 6.8285
# Time : 2m 22s     | Epoch [247/30000]	Train loss: 8.2312	 Vali loss: 6.1562
# Time : 2m 22s     | Epoch [248/30000]	Train loss: 8.2409	 Vali loss: 5.2477
# Time : 2m 23s     | Epoch [249/30000]	Train loss: 8.3737	 Vali loss: 5.3081
# Time : 2m 23s     | Epoch [250/30000]	Train loss: 8.4117	 Vali loss: 5.3027
# ------------------Train Test------------------
# Now Epoch [250/30000]
# Test MAE: 5.5588	 Test Std.: 8.6612	Test R2 score: 0.7826
# ----------------------------------------------
# Time : 2m 24s     | Epoch [251/30000]	Train loss: 9.3696	 Vali loss: 8.5122
# Time : 2m 25s     | Epoch [252/30000]	Train loss: 8.6239	 Vali loss: 5.2460
# Time : 2m 25s     | Epoch [253/30000]	Train loss: 7.9164	 Vali loss: 6.1454
# Time : 2m 26s     | Epoch [254/30000]	Train loss: 8.3468	 Vali loss: 7.7012
# Time : 2m 26s     | Epoch [255/30000]	Train loss: 8.3091	 Vali loss: 5.5325
# Time : 2m 27s     | Epoch [256/30000]	Train loss: 8.0965	 Vali loss: 6.1689
# Time : 2m 27s     | Epoch [257/30000]	Train loss: 8.7443	 Vali loss: 5.5086
# Time : 2m 28s     | Epoch [258/30000]	Train loss: 8.2497	 Vali loss: 6.0450
# Time : 2m 29s     | Epoch [259/30000]	Train loss: 8.0779	 Vali loss: 6.1369
# Time : 2m 29s     | Epoch [260/30000]	Train loss: 8.4133	 Vali loss: 6.4722
# Time : 2m 30s     | Epoch [261/30000]	Train loss: 7.9076	 Vali loss: 6.4154
# Time : 2m 30s     | Epoch [262/30000]	Train loss: 8.4512	 Vali loss: 7.9564
# Time : 2m 31s     | Epoch [263/30000]	Train loss: 8.4743	 Vali loss: 5.6148
# Time : 2m 32s     | Epoch [264/30000]	Train loss: 8.1805	 Vali loss: 5.2652
# Time : 2m 32s     | Epoch [265/30000]	Train loss: 8.4404	 Vali loss: 5.3112
# Time : 2m 33s     | Epoch [266/30000]	Train loss: 8.2780	 Vali loss: 7.1786
# Time : 2m 33s     | Epoch [267/30000]	Train loss: 7.8570	 Vali loss: 5.0392
# Time : 2m 34s     | Epoch [268/30000]	Train loss: 8.1606	 Vali loss: 7.4340
# Time : 2m 34s     | Epoch [269/30000]	Train loss: 8.7022	 Vali loss: 5.8572
# Time : 2m 35s     | Epoch [270/30000]	Train loss: 8.9608	 Vali loss: 5.5662
# Time : 2m 36s     | Epoch [271/30000]	Train loss: 7.9472	 Vali loss: 6.2809
# Time : 2m 36s     | Epoch [272/30000]	Train loss: 8.1791	 Vali loss: 5.8465
# Time : 2m 37s     | Epoch [273/30000]	Train loss: 9.0953	 Vali loss: 6.1158
# Time : 2m 37s     | Epoch [274/30000]	Train loss: 8.2191	 Vali loss: 5.3284
# Time : 2m 38s     | Epoch [275/30000]	Train loss: 8.0292	 Vali loss: 6.0029
# ------------------Train Test------------------
# Now Epoch [275/30000]
# Test MAE: 7.2394	 Test Std.: 8.6315	Test R2 score: 0.7185
# ----------------------------------------------
# Time : 2m 38s     | Epoch [276/30000]	Train loss: 8.0115	 Vali loss: 6.2813
# Time : 2m 39s     | Epoch [277/30000]	Train loss: 8.1524	 Vali loss: 6.1405
# Time : 2m 40s     | Epoch [278/30000]	Train loss: 8.1653	 Vali loss: 6.4122
# Time : 2m 40s     | Epoch [279/30000]	Train loss: 8.3818	 Vali loss: 9.3686
# Time : 2m 41s     | Epoch [280/30000]	Train loss: 8.8294	 Vali loss: 5.1655
# Time : 2m 41s     | Epoch [281/30000]	Train loss: 8.0330	 Vali loss: 6.2935
# Time : 2m 42s     | Epoch [282/30000]	Train loss: 8.6646	 Vali loss: 5.5555
# Time : 2m 42s     | Epoch [283/30000]	Train loss: 7.8613	 Vali loss: 6.9946
# Time : 2m 43s     | Epoch [284/30000]	Train loss: 8.2403	 Vali loss: 5.1426
# Time : 2m 44s     | Epoch [285/30000]	Train loss: 7.9683	 Vali loss: 5.6339
# Time : 2m 44s     | Epoch [286/30000]	Train loss: 8.2946	 Vali loss: 4.8468
# Time : 2m 45s     | Epoch [287/30000]	Train loss: 8.3838	 Vali loss: 5.2594
# Time : 2m 45s     | Epoch [288/30000]	Train loss: 8.2951	 Vali loss: 5.4956
# Time : 2m 46s     | Epoch [289/30000]	Train loss: 8.6161	 Vali loss: 5.0776
# Time : 2m 46s     | Epoch [290/30000]	Train loss: 8.3517	 Vali loss: 5.7760
# Time : 2m 47s     | Epoch [291/30000]	Train loss: 8.4424	 Vali loss: 5.4325
# Time : 2m 48s     | Epoch [292/30000]	Train loss: 8.4470	 Vali loss: 6.2160
# Time : 2m 48s     | Epoch [293/30000]	Train loss: 8.7012	 Vali loss: 5.2790
# Time : 2m 49s     | Epoch [294/30000]	Train loss: 8.2053	 Vali loss: 5.7516
# Time : 2m 49s     | Epoch [295/30000]	Train loss: 7.9081	 Vali loss: 7.8750
# Time : 2m 50s     | Epoch [296/30000]	Train loss: 8.5957	 Vali loss: 5.5291
# Time : 2m 50s     | Epoch [297/30000]	Train loss: 8.1288	 Vali loss: 6.2097
# Time : 2m 51s     | Epoch [298/30000]	Train loss: 8.9357	 Vali loss: 8.4606
# Time : 2m 52s     | Epoch [299/30000]	Train loss: 8.2911	 Vali loss: 5.4522
# Time : 2m 52s     | Epoch [300/30000]	Train loss: 8.1207	 Vali loss: 5.5558
# ------------------Train Test------------------
# Now Epoch [300/30000]
# Test MAE: 6.4889	 Test Std.: 8.7284	Test R2 score: 0.7461
# ----------------------------------------------
# Time : 2m 53s     | Epoch [301/30000]	Train loss: 8.3280	 Vali loss: 5.9902
# Time : 2m 53s     | Epoch [302/30000]	Train loss: 8.0967	 Vali loss: 5.5551
# Time : 2m 54s     | Epoch [303/30000]	Train loss: 7.9736	 Vali loss: 6.1455
# Time : 2m 55s     | Epoch [304/30000]	Train loss: 8.0944	 Vali loss: 7.1919
# Time : 2m 55s     | Epoch [305/30000]	Train loss: 8.2357	 Vali loss: 5.5926
# Time : 2m 56s     | Epoch [306/30000]	Train loss: 7.9284	 Vali loss: 5.1164
# Time : 2m 56s     | Epoch [307/30000]	Train loss: 8.0271	 Vali loss: 5.0830
# Time : 2m 57s     | Epoch [308/30000]	Train loss: 8.1586	 Vali loss: 6.8431
# Time : 2m 57s     | Epoch [309/30000]	Train loss: 8.3887	 Vali loss: 6.6276
# Time : 2m 58s     | Epoch [310/30000]	Train loss: 8.4393	 Vali loss: 5.6530
# Time : 2m 59s     | Epoch [311/30000]	Train loss: 8.5584	 Vali loss: 8.3171
# Time : 2m 59s     | Epoch [312/30000]	Train loss: 8.7590	 Vali loss: 6.2795
# Time : 3m 0s      | Epoch [313/30000]	Train loss: 8.5611	 Vali loss: 5.1660
# Time : 3m 0s      | Epoch [314/30000]	Train loss: 8.1938	 Vali loss: 5.4163
# Time : 3m 1s      | Epoch [315/30000]	Train loss: 8.4284	 Vali loss: 5.8384
# Time : 3m 1s      | Epoch [316/30000]	Train loss: 8.4694	 Vali loss: 5.5150
# Time : 3m 2s      | Epoch [317/30000]	Train loss: 8.1783	 Vali loss: 6.0184
# Time : 3m 3s      | Epoch [318/30000]	Train loss: 8.3689	 Vali loss: 7.6135
# Time : 3m 3s      | Epoch [319/30000]	Train loss: 8.3496	 Vali loss: 5.0541
# Time : 3m 4s      | Epoch [320/30000]	Train loss: 8.1302	 Vali loss: 5.1565
# Time : 3m 4s      | Epoch [321/30000]	Train loss: 8.4861	 Vali loss: 5.0592
# Time : 3m 5s      | Epoch [322/30000]	Train loss: 8.1456	 Vali loss: 5.0683
# Time : 3m 5s      | Epoch [323/30000]	Train loss: 7.8653	 Vali loss: 6.3361
# Time : 3m 6s      | Epoch [324/30000]	Train loss: 8.2226	 Vali loss: 5.5665
# Time : 3m 7s      | Epoch [325/30000]	Train loss: 8.4313	 Vali loss: 5.2452
# ------------------Train Test------------------
# Now Epoch [325/30000]
# Test MAE: 5.9950	 Test Std.: 8.5513	Test R2 score: 0.7741
# ----------------------------------------------
# Time : 3m 7s      | Epoch [326/30000]	Train loss: 8.3605	 Vali loss: 5.4091
# Time : 3m 8s      | Epoch [327/30000]	Train loss: 8.1607	 Vali loss: 5.5837
# Time : 3m 8s      | Epoch [328/30000]	Train loss: 8.3358	 Vali loss: 5.5382
# Time : 3m 9s      | Epoch [329/30000]	Train loss: 8.2370	 Vali loss: 7.3378
# Time : 3m 10s     | Epoch [330/30000]	Train loss: 8.3177	 Vali loss: 5.6999
# Time : 3m 10s     | Epoch [331/30000]	Train loss: 7.8563	 Vali loss: 5.2197
# Time : 3m 11s     | Epoch [332/30000]	Train loss: 8.5086	 Vali loss: 10.8412
# Time : 3m 11s     | Epoch [333/30000]	Train loss: 8.8382	 Vali loss: 5.1138
# Time : 3m 12s     | Epoch [334/30000]	Train loss: 8.2246	 Vali loss: 6.4760
# Time : 3m 12s     | Epoch [335/30000]	Train loss: 8.0837	 Vali loss: 6.2605
# Time : 3m 13s     | Epoch [336/30000]	Train loss: 8.4432	 Vali loss: 7.9795
# Time : 3m 14s     | Epoch [337/30000]	Train loss: 8.8482	 Vali loss: 6.3433
# Time : 3m 14s     | Epoch [338/30000]	Train loss: 7.9246	 Vali loss: 6.5471
# Time : 3m 15s     | Epoch [339/30000]	Train loss: 8.0101	 Vali loss: 7.0666
# Time : 3m 15s     | Epoch [340/30000]	Train loss: 8.0555	 Vali loss: 5.3279
# Time : 3m 16s     | Epoch [341/30000]	Train loss: 7.9473	 Vali loss: 7.1499
# Time : 3m 16s     | Epoch [342/30000]	Train loss: 8.1349	 Vali loss: 5.4512
# Time : 3m 17s     | Epoch [343/30000]	Train loss: 7.8954	 Vali loss: 6.6541
# Time : 3m 18s     | Epoch [344/30000]	Train loss: 8.0988	 Vali loss: 5.7668
# Time : 3m 18s     | Epoch [345/30000]	Train loss: 8.4383	 Vali loss: 5.3143
# Time : 3m 19s     | Epoch [346/30000]	Train loss: 8.0335	 Vali loss: 5.1660
# Time : 3m 19s     | Epoch [347/30000]	Train loss: 8.1655	 Vali loss: 7.1692
# Time : 3m 20s     | Epoch [348/30000]	Train loss: 8.6381	 Vali loss: 6.2992
# Time : 3m 20s     | Epoch [349/30000]	Train loss: 8.3540	 Vali loss: 6.8639
# Time : 3m 21s     | Epoch [350/30000]	Train loss: 8.1791	 Vali loss: 5.2677
# ------------------Train Test------------------
# Now Epoch [350/30000]
# Test MAE: 5.3210	 Test Std.: 8.5754	Test R2 score: 0.7886
# ----------------------------------------------
# Time : 3m 22s     | Epoch [351/30000]	Train loss: 7.9467	 Vali loss: 4.9614
# Time : 3m 22s     | Epoch [352/30000]	Train loss: 7.8390	 Vali loss: 6.8758
# Time : 3m 23s     | Epoch [353/30000]	Train loss: 8.2489	 Vali loss: 7.7374
# Time : 3m 23s     | Epoch [354/30000]	Train loss: 9.3241	 Vali loss: 8.2780
# Time : 3m 24s     | Epoch [355/30000]	Train loss: 8.3936	 Vali loss: 5.3414
# Time : 3m 25s     | Epoch [356/30000]	Train loss: 7.9619	 Vali loss: 5.7526
# Time : 3m 25s     | Epoch [357/30000]	Train loss: 8.2785	 Vali loss: 6.3600
# Time : 3m 26s     | Epoch [358/30000]	Train loss: 8.6023	 Vali loss: 8.4522
# Time : 3m 26s     | Epoch [359/30000]	Train loss: 8.0593	 Vali loss: 5.2816
# Time : 3m 27s     | Epoch [360/30000]	Train loss: 7.9082	 Vali loss: 5.1033
# Time : 3m 27s     | Epoch [361/30000]	Train loss: 8.1664	 Vali loss: 4.9048
# Time : 3m 28s     | Epoch [362/30000]	Train loss: 7.7759	 Vali loss: 5.9577
# Time : 3m 29s     | Epoch [363/30000]	Train loss: 8.0909	 Vali loss: 5.7064
# Time : 3m 29s     | Epoch [364/30000]	Train loss: 8.0155	 Vali loss: 6.0517
# Time : 3m 30s     | Epoch [365/30000]	Train loss: 7.9761	 Vali loss: 6.2262
# Time : 3m 30s     | Epoch [366/30000]	Train loss: 7.8745	 Vali loss: 5.1730
# Time : 3m 31s     | Epoch [367/30000]	Train loss: 8.4388	 Vali loss: 9.5879
# Time : 3m 31s     | Epoch [368/30000]	Train loss: 7.8897	 Vali loss: 5.7266
# Time : 3m 32s     | Epoch [369/30000]	Train loss: 8.1297	 Vali loss: 4.9015
# Time : 3m 33s     | Epoch [370/30000]	Train loss: 8.1915	 Vali loss: 5.5987
# Time : 3m 33s     | Epoch [371/30000]	Train loss: 7.9546	 Vali loss: 6.5707
# Time : 3m 34s     | Epoch [372/30000]	Train loss: 8.2147	 Vali loss: 8.0440
# Time : 3m 34s     | Epoch [373/30000]	Train loss: 8.1164	 Vali loss: 5.3740
# Time : 3m 35s     | Epoch [374/30000]	Train loss: 8.1922	 Vali loss: 5.4053
# Time : 3m 35s     | Epoch [375/30000]	Train loss: 8.0288	 Vali loss: 7.7861
# ------------------Train Test------------------
# Now Epoch [375/30000]
# Test MAE: 6.8428	 Test Std.: 8.3500	Test R2 score: 0.7446
# ----------------------------------------------
# Time : 3m 36s     | Epoch [376/30000]	Train loss: 8.3808	 Vali loss: 5.3375
# Time : 3m 37s     | Epoch [377/30000]	Train loss: 7.9268	 Vali loss: 5.1964
# Time : 3m 37s     | Epoch [378/30000]	Train loss: 8.3256	 Vali loss: 5.6476
# Time : 3m 38s     | Epoch [379/30000]	Train loss: 8.3470	 Vali loss: 6.6080
# Time : 3m 38s     | Epoch [380/30000]	Train loss: 8.6967	 Vali loss: 5.3102
# Time : 3m 39s     | Epoch [381/30000]	Train loss: 8.1268	 Vali loss: 5.9747
# Time : 3m 40s     | Epoch [382/30000]	Train loss: 8.3272	 Vali loss: 6.2003
# Time : 3m 40s     | Epoch [383/30000]	Train loss: 8.2226	 Vali loss: 5.3804
# Time : 3m 41s     | Epoch [384/30000]	Train loss: 8.2373	 Vali loss: 7.1107
# Time : 3m 41s     | Epoch [385/30000]	Train loss: 8.1616	 Vali loss: 5.4716
# Time : 3m 42s     | Epoch [386/30000]	Train loss: 8.7539	 Vali loss: 7.2377
# Time : 3m 42s     | Epoch [387/30000]	Train loss: 8.3867	 Vali loss: 5.4236
# Time : 3m 43s     | Epoch [388/30000]	Train loss: 8.1789	 Vali loss: 4.8940
# Time : 3m 44s     | Epoch [389/30000]	Train loss: 8.0561	 Vali loss: 5.4151
# Time : 3m 44s     | Epoch [390/30000]	Train loss: 8.1887	 Vali loss: 5.1637
# Time : 3m 45s     | Epoch [391/30000]	Train loss: 8.1113	 Vali loss: 5.6477
# Time : 3m 45s     | Epoch [392/30000]	Train loss: 8.5461	 Vali loss: 8.3555
# Time : 3m 46s     | Epoch [393/30000]	Train loss: 8.3560	 Vali loss: 7.4710
# Time : 3m 46s     | Epoch [394/30000]	Train loss: 7.8589	 Vali loss: 6.5866
# Time : 3m 47s     | Epoch [395/30000]	Train loss: 8.3826	 Vali loss: 6.0785
# Time : 3m 48s     | Epoch [396/30000]	Train loss: 8.2766	 Vali loss: 5.5091
# Time : 3m 48s     | Epoch [397/30000]	Train loss: 8.0882	 Vali loss: 5.7266
# Time : 3m 49s     | Epoch [398/30000]	Train loss: 8.0456	 Vali loss: 5.8395
# Time : 3m 49s     | Epoch [399/30000]	Train loss: 8.0134	 Vali loss: 4.9977
# Time : 3m 50s     | Epoch [400/30000]	Train loss: 7.9486	 Vali loss: 5.6371
# ------------------Train Test------------------
# Now Epoch [400/30000]
# Test MAE: 5.5080	 Test Std.: 8.3573	Test R2 score: 0.7972
# ----------------------------------------------
# Time : 3m 50s     | Epoch [401/30000]	Train loss: 8.2712	 Vali loss: 4.9942
# Time : 3m 51s     | Epoch [402/30000]	Train loss: 7.9231	 Vali loss: 5.1579
# Time : 3m 52s     | Epoch [403/30000]	Train loss: 7.9660	 Vali loss: 6.0174
# Time : 3m 52s     | Epoch [404/30000]	Train loss: 8.1334	 Vali loss: 6.8409
# Time : 3m 53s     | Epoch [405/30000]	Train loss: 7.8931	 Vali loss: 4.9705
# Time : 3m 53s     | Epoch [406/30000]	Train loss: 8.2602	 Vali loss: 4.9061
# Time : 3m 54s     | Epoch [407/30000]	Train loss: 7.5904	 Vali loss: 5.5364
# Time : 3m 54s     | Epoch [408/30000]	Train loss: 8.3661	 Vali loss: 5.4149
# Time : 3m 55s     | Epoch [409/30000]	Train loss: 8.3541	 Vali loss: 5.9037
# Time : 3m 56s     | Epoch [410/30000]	Train loss: 7.8986	 Vali loss: 5.3627
# Time : 3m 56s     | Epoch [411/30000]	Train loss: 8.4614	 Vali loss: 6.7556
# Time : 3m 57s     | Epoch [412/30000]	Train loss: 8.1519	 Vali loss: 5.0685
# Time : 3m 57s     | Epoch [413/30000]	Train loss: 8.2862	 Vali loss: 7.4474
# Time : 3m 58s     | Epoch [414/30000]	Train loss: 8.2843	 Vali loss: 8.1177
# Time : 3m 59s     | Epoch [415/30000]	Train loss: 8.1832	 Vali loss: 5.2570
# Time : 3m 59s     | Epoch [416/30000]	Train loss: 7.7953	 Vali loss: 5.2825
# Time : 4m 0s      | Epoch [417/30000]	Train loss: 8.0494	 Vali loss: 5.4100
# Time : 4m 0s      | Epoch [418/30000]	Train loss: 8.0802	 Vali loss: 6.8360
# Time : 4m 1s      | Epoch [419/30000]	Train loss: 8.4441	 Vali loss: 6.0288
# Time : 4m 1s      | Epoch [420/30000]	Train loss: 7.8669	 Vali loss: 6.6051
# Time : 4m 2s      | Epoch [421/30000]	Train loss: 7.8848	 Vali loss: 5.6531
# Time : 4m 3s      | Epoch [422/30000]	Train loss: 8.8900	 Vali loss: 6.3018
# Time : 4m 3s      | Epoch [423/30000]	Train loss: 8.3479	 Vali loss: 6.1453
# Time : 4m 4s      | Epoch [424/30000]	Train loss: 8.3738	 Vali loss: 5.4861
# Time : 4m 4s      | Epoch [425/30000]	Train loss: 7.9804	 Vali loss: 5.1867
# ------------------Train Test------------------
# Now Epoch [425/30000]
# Test MAE: 5.3137	 Test Std.: 9.0555	Test R2 score: 0.7635
# ----------------------------------------------
# Time : 4m 5s      | Epoch [426/30000]	Train loss: 7.5655	 Vali loss: 6.4753
# Time : 4m 5s      | Epoch [427/30000]	Train loss: 7.9076	 Vali loss: 5.4880
# Time : 4m 6s      | Epoch [428/30000]	Train loss: 7.8957	 Vali loss: 4.9651
# Time : 4m 7s      | Epoch [429/30000]	Train loss: 8.0718	 Vali loss: 5.2236
# Time : 4m 7s      | Epoch [430/30000]	Train loss: 8.1471	 Vali loss: 8.8530
# Time : 4m 8s      | Epoch [431/30000]	Train loss: 8.6464	 Vali loss: 5.3559
# Time : 4m 8s      | Epoch [432/30000]	Train loss: 7.9325	 Vali loss: 5.0391
# Time : 4m 9s      | Epoch [433/30000]	Train loss: 7.9330	 Vali loss: 7.2975
# Time : 4m 9s      | Epoch [434/30000]	Train loss: 8.0424	 Vali loss: 6.2381
# Time : 4m 10s     | Epoch [435/30000]	Train loss: 7.7782	 Vali loss: 5.3998
# Time : 4m 11s     | Epoch [436/30000]	Train loss: 7.8289	 Vali loss: 6.5695
# Time : 4m 11s     | Epoch [437/30000]	Train loss: 7.9827	 Vali loss: 6.4398
# Time : 4m 12s     | Epoch [438/30000]	Train loss: 8.4587	 Vali loss: 5.5837
# Time : 4m 12s     | Epoch [439/30000]	Train loss: 7.9731	 Vali loss: 5.2560
# Time : 4m 13s     | Epoch [440/30000]	Train loss: 7.8929	 Vali loss: 5.3487
# Time : 4m 13s     | Epoch [441/30000]	Train loss: 7.6458	 Vali loss: 5.2443
# Time : 4m 14s     | Epoch [442/30000]	Train loss: 7.7895	 Vali loss: 5.4594
# Time : 4m 15s     | Epoch [443/30000]	Train loss: 8.1711	 Vali loss: 6.1859
# Time : 4m 15s     | Epoch [444/30000]	Train loss: 7.7715	 Vali loss: 5.0992
# Time : 4m 16s     | Epoch [445/30000]	Train loss: 8.2310	 Vali loss: 5.0866
# Time : 4m 16s     | Epoch [446/30000]	Train loss: 8.2732	 Vali loss: 5.1250
# Time : 4m 17s     | Epoch [447/30000]	Train loss: 7.7269	 Vali loss: 8.9435
# Time : 4m 17s     | Epoch [448/30000]	Train loss: 8.4276	 Vali loss: 7.1509
# Time : 4m 18s     | Epoch [449/30000]	Train loss: 8.2818	 Vali loss: 7.7750
# Time : 4m 19s     | Epoch [450/30000]	Train loss: 8.2465	 Vali loss: 6.1061
# ------------------Train Test------------------
# Now Epoch [450/30000]
# Test MAE: 5.5947	 Test Std.: 8.1976	Test R2 score: 0.7980
# ----------------------------------------------
# Time : 4m 19s     | Epoch [451/30000]	Train loss: 7.9192	 Vali loss: 5.5029
# Time : 4m 20s     | Epoch [452/30000]	Train loss: 8.3470	 Vali loss: 6.6038
# Time : 4m 20s     | Epoch [453/30000]	Train loss: 8.4081	 Vali loss: 8.3782
# Time : 4m 21s     | Epoch [454/30000]	Train loss: 8.2430	 Vali loss: 5.0565
# Time : 4m 22s     | Epoch [455/30000]	Train loss: 7.9939	 Vali loss: 5.2596
# Time : 4m 22s     | Epoch [456/30000]	Train loss: 7.8984	 Vali loss: 6.4805
# Time : 4m 23s     | Epoch [457/30000]	Train loss: 8.0278	 Vali loss: 5.4510
# Time : 4m 23s     | Epoch [458/30000]	Train loss: 8.1298	 Vali loss: 5.7649
# Time : 4m 24s     | Epoch [459/30000]	Train loss: 7.8285	 Vali loss: 7.2725
# Time : 4m 24s     | Epoch [460/30000]	Train loss: 7.9884	 Vali loss: 5.6596
# Time : 4m 25s     | Epoch [461/30000]	Train loss: 8.1867	 Vali loss: 6.3440
# Time : 4m 26s     | Epoch [462/30000]	Train loss: 8.1987	 Vali loss: 5.6109
# Time : 4m 26s     | Epoch [463/30000]	Train loss: 7.9612	 Vali loss: 5.4552
# Time : 4m 27s     | Epoch [464/30000]	Train loss: 8.6987	 Vali loss: 5.0069
# Time : 4m 27s     | Epoch [465/30000]	Train loss: 8.1802	 Vali loss: 6.9316
# Time : 4m 28s     | Epoch [466/30000]	Train loss: 7.9094	 Vali loss: 5.2866
# Time : 4m 28s     | Epoch [467/30000]	Train loss: 8.8485	 Vali loss: 5.0392
# Time : 4m 29s     | Epoch [468/30000]	Train loss: 7.9719	 Vali loss: 5.5349
# Time : 4m 30s     | Epoch [469/30000]	Train loss: 7.8085	 Vali loss: 4.8566
# Time : 4m 30s     | Epoch [470/30000]	Train loss: 7.9265	 Vali loss: 5.0753
# Time : 4m 31s     | Epoch [471/30000]	Train loss: 7.7837	 Vali loss: 5.5094
# Time : 4m 31s     | Epoch [472/30000]	Train loss: 7.8372	 Vali loss: 6.2991
# Time : 4m 32s     | Epoch [473/30000]	Train loss: 8.1494	 Vali loss: 5.1224
# Time : 4m 32s     | Epoch [474/30000]	Train loss: 7.6523	 Vali loss: 5.2876
# Time : 4m 33s     | Epoch [475/30000]	Train loss: 7.7026	 Vali loss: 5.3287
# ------------------Train Test------------------
# Now Epoch [475/30000]
# Test MAE: 5.0366	 Test Std.: 8.5644	Test R2 score: 0.7891
# ----------------------------------------------
# Time : 4m 34s     | Epoch [476/30000]	Train loss: 7.6584	 Vali loss: 5.4977
# Time : 4m 34s     | Epoch [477/30000]	Train loss: 7.8523	 Vali loss: 5.6481
# Time : 4m 35s     | Epoch [478/30000]	Train loss: 8.4447	 Vali loss: 5.3383
# Time : 4m 35s     | Epoch [479/30000]	Train loss: 8.0841	 Vali loss: 5.1666
# Time : 4m 36s     | Epoch [480/30000]	Train loss: 8.0467	 Vali loss: 6.0976
# Time : 4m 36s     | Epoch [481/30000]	Train loss: 7.8518	 Vali loss: 5.2359
# Time : 4m 37s     | Epoch [482/30000]	Train loss: 8.0186	 Vali loss: 5.0115
# Time : 4m 38s     | Epoch [483/30000]	Train loss: 8.0708	 Vali loss: 5.5657
# Time : 4m 38s     | Epoch [484/30000]	Train loss: 8.0209	 Vali loss: 5.6968
# Time : 4m 39s     | Epoch [485/30000]	Train loss: 8.0897	 Vali loss: 8.2669
# Time : 4m 39s     | Epoch [486/30000]	Train loss: 8.0864	 Vali loss: 5.3559
# Time : 4m 40s     | Epoch [487/30000]	Train loss: 8.1497	 Vali loss: 5.3116
# Time : 4m 40s     | Epoch [488/30000]	Train loss: 8.5590	 Vali loss: 5.4790
# Time : 4m 41s     | Epoch [489/30000]	Train loss: 7.9531	 Vali loss: 5.8250
# Time : 4m 42s     | Epoch [490/30000]	Train loss: 7.8225	 Vali loss: 5.4453
# Time : 4m 42s     | Epoch [491/30000]	Train loss: 7.7319	 Vali loss: 5.2292
# Time : 4m 43s     | Epoch [492/30000]	Train loss: 7.9749	 Vali loss: 6.5740
# Time : 4m 43s     | Epoch [493/30000]	Train loss: 7.6825	 Vali loss: 5.6127
# Time : 4m 44s     | Epoch [494/30000]	Train loss: 7.6553	 Vali loss: 5.2347
# Time : 4m 44s     | Epoch [495/30000]	Train loss: 8.4855	 Vali loss: 5.5711
# Time : 4m 45s     | Epoch [496/30000]	Train loss: 8.1091	 Vali loss: 8.5560
# Time : 4m 46s     | Epoch [497/30000]	Train loss: 8.2248	 Vali loss: 5.5182
# Time : 4m 46s     | Epoch [498/30000]	Train loss: 8.1665	 Vali loss: 6.9469
# Time : 4m 47s     | Epoch [499/30000]	Train loss: 8.0117	 Vali loss: 5.7373
# Time : 4m 47s     | Epoch [500/30000]	Train loss: 8.1470	 Vali loss: 6.7527
# ------------------Train Test------------------
# Now Epoch [500/30000]
# Test MAE: 6.0246	 Test Std.: 8.3091	Test R2 score: 0.7845
# ----------------------------------------------
# Time : 4m 48s     | Epoch [501/30000]	Train loss: 7.9257	 Vali loss: 8.7069
# Time : 4m 48s     | Epoch [502/30000]	Train loss: 7.7262	 Vali loss: 6.5426
# Time : 4m 49s     | Epoch [503/30000]	Train loss: 7.9224	 Vali loss: 4.9678
# Time : 4m 50s     | Epoch [504/30000]	Train loss: 7.8475	 Vali loss: 5.5323
# Time : 4m 50s     | Epoch [505/30000]	Train loss: 7.9458	 Vali loss: 6.5555
# Time : 4m 51s     | Epoch [506/30000]	Train loss: 8.1121	 Vali loss: 8.2186
# Time : 4m 51s     | Epoch [507/30000]	Train loss: 8.0147	 Vali loss: 6.1175
# Time : 4m 52s     | Epoch [508/30000]	Train loss: 8.0605	 Vali loss: 5.0767
# Time : 4m 53s     | Epoch [509/30000]	Train loss: 7.6188	 Vali loss: 5.5364
# Time : 4m 53s     | Epoch [510/30000]	Train loss: 7.9464	 Vali loss: 4.9630
# Time : 4m 54s     | Epoch [511/30000]	Train loss: 8.3364	 Vali loss: 5.7272
# Time : 4m 54s     | Epoch [512/30000]	Train loss: 8.5074	 Vali loss: 10.2525
# Time : 4m 55s     | Epoch [513/30000]	Train loss: 8.3222	 Vali loss: 6.2985
# Time : 4m 55s     | Epoch [514/30000]	Train loss: 8.1009	 Vali loss: 5.9002
# Time : 4m 56s     | Epoch [515/30000]	Train loss: 8.2794	 Vali loss: 5.8463
# Time : 4m 57s     | Epoch [516/30000]	Train loss: 8.2100	 Vali loss: 8.2503
# Time : 4m 57s     | Epoch [517/30000]	Train loss: 8.0630	 Vali loss: 5.3586
# Time : 4m 58s     | Epoch [518/30000]	Train loss: 7.9160	 Vali loss: 5.6990
# Time : 4m 58s     | Epoch [519/30000]	Train loss: 7.7198	 Vali loss: 5.0295
# Time : 4m 59s     | Epoch [520/30000]	Train loss: 8.0380	 Vali loss: 5.1879
# Time : 5m 0s      | Epoch [521/30000]	Train loss: 8.4246	 Vali loss: 7.7109
# Time : 5m 0s      | Epoch [522/30000]	Train loss: 7.9417	 Vali loss: 6.0390
# Time : 5m 1s      | Epoch [523/30000]	Train loss: 8.3451	 Vali loss: 6.2864
# Time : 5m 1s      | Epoch [524/30000]	Train loss: 8.0591	 Vali loss: 5.0396
# Time : 5m 2s      | Epoch [525/30000]	Train loss: 7.4280	 Vali loss: 5.7830
# ------------------Train Test------------------
# Now Epoch [525/30000]
# Test MAE: 5.2874	 Test Std.: 7.5598	Test R2 score: 0.8340
# ----------------------------------------------
# Time : 5m 3s      | Epoch [526/30000]	Train loss: 7.9208	 Vali loss: 5.4362
# Time : 5m 3s      | Epoch [527/30000]	Train loss: 8.0861	 Vali loss: 5.1250
# Time : 5m 4s      | Epoch [528/30000]	Train loss: 7.4834	 Vali loss: 6.0478
# Time : 5m 4s      | Epoch [529/30000]	Train loss: 7.4907	 Vali loss: 5.3194
# Time : 5m 5s      | Epoch [530/30000]	Train loss: 7.8156	 Vali loss: 5.5776
# Time : 5m 6s      | Epoch [531/30000]	Train loss: 7.7807	 Vali loss: 4.9120
# Time : 5m 6s      | Epoch [532/30000]	Train loss: 7.9348	 Vali loss: 7.4740
# Time : 5m 7s      | Epoch [533/30000]	Train loss: 7.9561	 Vali loss: 7.9251
# Time : 5m 7s      | Epoch [534/30000]	Train loss: 7.5797	 Vali loss: 5.3490
# Time : 5m 8s      | Epoch [535/30000]	Train loss: 8.3435	 Vali loss: 6.5963
# Time : 5m 8s      | Epoch [536/30000]	Train loss: 8.3278	 Vali loss: 5.3680
# Time : 5m 9s      | Epoch [537/30000]	Train loss: 7.5989	 Vali loss: 6.2218
# Time : 5m 10s     | Epoch [538/30000]	Train loss: 8.0118	 Vali loss: 6.3685
# Time : 5m 10s     | Epoch [539/30000]	Train loss: 8.0531	 Vali loss: 6.6500
# Time : 5m 11s     | Epoch [540/30000]	Train loss: 7.6714	 Vali loss: 6.8238
# Time : 5m 11s     | Epoch [541/30000]	Train loss: 8.6759	 Vali loss: 5.5744
# Time : 5m 12s     | Epoch [542/30000]	Train loss: 8.1061	 Vali loss: 5.1254
# Time : 5m 12s     | Epoch [543/30000]	Train loss: 7.6126	 Vali loss: 5.6094
# Time : 5m 13s     | Epoch [544/30000]	Train loss: 7.7919	 Vali loss: 5.1639
# Time : 5m 14s     | Epoch [545/30000]	Train loss: 8.2810	 Vali loss: 8.1218
# Time : 5m 14s     | Epoch [546/30000]	Train loss: 7.9893	 Vali loss: 5.3108
# Time : 5m 15s     | Epoch [547/30000]	Train loss: 8.3753	 Vali loss: 5.5828
# Time : 5m 15s     | Epoch [548/30000]	Train loss: 7.6461	 Vali loss: 5.1312
# Time : 5m 16s     | Epoch [549/30000]	Train loss: 7.8652	 Vali loss: 5.5476
# Time : 5m 16s     | Epoch [550/30000]	Train loss: 7.7530	 Vali loss: 5.6321
# ------------------Train Test------------------
# Now Epoch [550/30000]
# Test MAE: 4.9673	 Test Std.: 7.7844	Test R2 score: 0.8241
# ----------------------------------------------
# Time : 5m 17s     | Epoch [551/30000]	Train loss: 8.4301	 Vali loss: 6.6372
# Time : 5m 18s     | Epoch [552/30000]	Train loss: 8.6442	 Vali loss: 5.1049
# Time : 5m 18s     | Epoch [553/30000]	Train loss: 7.7747	 Vali loss: 5.5382
# Time : 5m 19s     | Epoch [554/30000]	Train loss: 7.7024	 Vali loss: 6.9638
# Time : 5m 19s     | Epoch [555/30000]	Train loss: 8.5060	 Vali loss: 5.8604
# Time : 5m 20s     | Epoch [556/30000]	Train loss: 7.8156	 Vali loss: 6.4034
# Time : 5m 20s     | Epoch [557/30000]	Train loss: 7.9685	 Vali loss: 5.1660
# Time : 5m 21s     | Epoch [558/30000]	Train loss: 7.8285	 Vali loss: 7.0579
# Time : 5m 22s     | Epoch [559/30000]	Train loss: 8.1254	 Vali loss: 7.3485
# Time : 5m 22s     | Epoch [560/30000]	Train loss: 7.8141	 Vali loss: 6.0827
# Time : 5m 23s     | Epoch [561/30000]	Train loss: 8.3137	 Vali loss: 6.5435
# Time : 5m 23s     | Epoch [562/30000]	Train loss: 8.2563	 Vali loss: 5.0013
# Time : 5m 24s     | Epoch [563/30000]	Train loss: 8.0030	 Vali loss: 5.2106
# Time : 5m 24s     | Epoch [564/30000]	Train loss: 8.3494	 Vali loss: 11.6580
# Time : 5m 25s     | Epoch [565/30000]	Train loss: 8.1952	 Vali loss: 7.3961
# Time : 5m 26s     | Epoch [566/30000]	Train loss: 7.9449	 Vali loss: 4.9635
# Time : 5m 26s     | Epoch [567/30000]	Train loss: 7.7995	 Vali loss: 6.8626
# Time : 5m 27s     | Epoch [568/30000]	Train loss: 8.0767	 Vali loss: 4.6474
# Time : 5m 27s     | Epoch [569/30000]	Train loss: 7.4680	 Vali loss: 6.1463
# Time : 5m 28s     | Epoch [570/30000]	Train loss: 7.6980	 Vali loss: 5.9698
# Time : 5m 28s     | Epoch [571/30000]	Train loss: 8.1174	 Vali loss: 5.6744
# Time : 5m 29s     | Epoch [572/30000]	Train loss: 7.9304	 Vali loss: 5.8930
# Time : 5m 30s     | Epoch [573/30000]	Train loss: 8.1692	 Vali loss: 5.1122
# Time : 5m 30s     | Epoch [574/30000]	Train loss: 7.5439	 Vali loss: 4.8850
# Time : 5m 31s     | Epoch [575/30000]	Train loss: 7.8915	 Vali loss: 5.0801
# ------------------Train Test------------------
# Now Epoch [575/30000]
# Test MAE: 5.7307	 Test Std.: 8.2617	Test R2 score: 0.7859
# ----------------------------------------------
# Time : 5m 31s     | Epoch [576/30000]	Train loss: 8.1506	 Vali loss: 7.2282
# Time : 5m 32s     | Epoch [577/30000]	Train loss: 7.4295	 Vali loss: 5.1004
# Time : 5m 32s     | Epoch [578/30000]	Train loss: 7.7650	 Vali loss: 6.2991
# Time : 5m 33s     | Epoch [579/30000]	Train loss: 7.5558	 Vali loss: 4.9939
# ...
# ----------------------------------------------
# Time : 11m 31s    | Epoch [1201/30000]	Train loss: 5.8166	 Vali loss: 8.7705
# Time : 11m 32s    | Epoch [1202/30000]	Train loss: 5.7217	 Vali loss: 9.8137
# Time : 11m 32s    | Epoch [1203/30000]	Train loss: 5.8701	 Vali loss: 9.3055
# Time : 11m 33s    | Epoch [1204/30000]	Train loss: 5.8538	 Vali loss: 10.1098
# Time : 11m 34s    | Epoch [1205/30000]	Train loss: 5.5357	 Vali loss: 10.4993
# Time : 11m 34s    | Epoch [1206/30000]	Train loss: 5.8579	 Vali loss: 8.1513
# Time : 11m 35s    | Epoch [1207/30000]	Train loss: 5.5126	 Vali loss: 9.2947
# Time : 11m 35s    | Epoch [1208/30000]	Train loss: 5.8547	 Vali loss: 9.3462
# Time : 11m 36s    | Epoch [1209/30000]	Train loss: 5.8665	 Vali loss: 9.4417
# Time : 11m 36s    | Epoch [1210/30000]	Train loss: 5.4687	 Vali loss: 9.7453
# Time : 11m 37s    | Epoch [1211/30000]	Train loss: 5.8934	 Vali loss: 9.9346
# Time : 11m 38s    | Epoch [1212/30000]	Train loss: 5.6497	 Vali loss: 10.0408
# Time : 11m 38s    | Epoch [1213/30000]	Train loss: 5.8181	 Vali loss: 9.6048
# Time : 11m 39s    | Epoch [1214/30000]	Train loss: 5.8171	 Vali loss: 8.9470
# Time : 11m 39s    | Epoch [1215/30000]	Train loss: 5.6334	 Vali loss: 7.4277
# Time : 11m 40s    | Epoch [1216/30000]	Train loss: 5.6082	 Vali loss: 10.0693
# Time : 11m 40s    | Epoch [1217/30000]	Train loss: 5.7312	 Vali loss: 9.2418
# Time : 11m 41s    | Epoch [1218/30000]	Train loss: 5.9016	 Vali loss: 8.0383
# Time : 11m 42s    | Epoch [1219/30000]	Train loss: 5.6776	 Vali loss: 8.6594
# Time : 11m 42s    | Epoch [1220/30000]	Train loss: 5.5172	 Vali loss: 8.8674
# Time : 11m 43s    | Epoch [1221/30000]	Train loss: 5.6395	 Vali loss: 10.7884
# Time : 11m 43s    | Epoch [1222/30000]	Train loss: 5.9456	 Vali loss: 10.2277
# Time : 11m 44s    | Epoch [1223/30000]	Train loss: 5.8532	 Vali loss: 10.5831
# Time : 11m 45s    | Epoch [1224/30000]	Train loss: 5.6162	 Vali loss: 9.4669
# Time : 11m 45s    | Epoch [1225/30000]	Train loss: 5.8461	 Vali loss: 10.6399
# ------------------Train Test------------------
# Now Epoch [1225/30000]
# Test MAE: 8.8952	 Test Std.: 9.7773	Test R2 score: 0.5558
# ----------------------------------------------
# Time : 11m 46s    | Epoch [1226/30000]	Train loss: 5.7359	 Vali loss: 9.6939
# Time : 11m 46s    | Epoch [1227/30000]	Train loss: 5.7184	 Vali loss: 10.6783
# Time : 11m 47s    | Epoch [1228/30000]	Train loss: 5.6749	 Vali loss: 9.3786
# Time : 11m 48s    | Epoch [1229/30000]	Train loss: 5.6469	 Vali loss: 9.4860
# Time : 11m 48s    | Epoch [1230/30000]	Train loss: 5.3550	 Vali loss: 10.0440
# Time : 11m 49s    | Epoch [1231/30000]	Train loss: 5.8041	 Vali loss: 8.1997
# Time : 11m 49s    | Epoch [1232/30000]	Train loss: 5.9341	 Vali loss: 8.7465
# Time : 11m 50s    | Epoch [1233/30000]	Train loss: 5.5428	 Vali loss: 8.8877
# Time : 11m 50s    | Epoch [1234/30000]	Train loss: 5.9318	 Vali loss: 8.9444
# Time : 11m 51s    | Epoch [1235/30000]	Train loss: 5.7100	 Vali loss: 9.3638
# Time : 11m 52s    | Epoch [1236/30000]	Train loss: 6.1403	 Vali loss: 9.1760
# Time : 11m 52s    | Epoch [1237/30000]	Train loss: 5.7160	 Vali loss: 9.5317
# Time : 11m 53s    | Epoch [1238/30000]	Train loss: 5.6624	 Vali loss: 10.3886
# Time : 11m 53s    | Epoch [1239/30000]	Train loss: 5.6654	 Vali loss: 9.3608
# Time : 11m 54s    | Epoch [1240/30000]	Train loss: 5.7192	 Vali loss: 9.2549
# Time : 11m 54s    | Epoch [1241/30000]	Train loss: 5.5489	 Vali loss: 10.4270
# Time : 11m 55s    | Epoch [1242/30000]	Train loss: 5.5896	 Vali loss: 9.5398
# Time : 11m 56s    | Epoch [1243/30000]	Train loss: 5.7897	 Vali loss: 10.0314
# Time : 11m 56s    | Epoch [1244/30000]	Train loss: 5.8079	 Vali loss: 10.2228
# Time : 11m 57s    | Epoch [1245/30000]	Train loss: 5.5300	 Vali loss: 8.6859
# Time : 11m 57s    | Epoch [1246/30000]	Train loss: 5.5862	 Vali loss: 7.8281
# Time : 11m 58s    | Epoch [1247/30000]	Train loss: 5.9531	 Vali loss: 8.7648
# Time : 11m 59s    | Epoch [1248/30000]	Train loss: 5.7636	 Vali loss: 9.7348
# Time : 11m 59s    | Epoch [1249/30000]	Train loss: 5.9666	 Vali loss: 10.5662
# Time : 12m 0s     | Epoch [1250/30000]	Train loss: 5.5547	 Vali loss: 9.8817
# ------------------Train Test------------------
# Now Epoch [1250/30000]
# Test MAE: 8.3149	 Test Std.: 9.9280	Test R2 score: 0.5672
# ----------------------------------------------
# Time : 12m 0s     | Epoch [1251/30000]	Train loss: 5.7098	 Vali loss: 8.6351
# Time : 12m 1s     | Epoch [1252/30000]	Train loss: 5.5422	 Vali loss: 8.7539
# Time : 12m 1s     | Epoch [1253/30000]	Train loss: 5.6407	 Vali loss: 7.6515
# Time : 12m 2s     | Epoch [1254/30000]	Train loss: 5.7189	 Vali loss: 10.8934
# Time : 12m 3s     | Epoch [1255/30000]	Train loss: 5.8708	 Vali loss: 10.5100
# Time : 12m 3s     | Epoch [1256/30000]	Train loss: 5.8070	 Vali loss: 9.3788
# Time : 12m 4s     | Epoch [1257/30000]	Train loss: 5.7758	 Vali loss: 7.8661
# Time : 12m 4s     | Epoch [1258/30000]	Train loss: 5.7841	 Vali loss: 9.2418
# Time : 12m 5s     | Epoch [1259/30000]	Train loss: 5.5524	 Vali loss: 9.0785
# Time : 12m 5s     | Epoch [1260/30000]	Train loss: 5.5115	 Vali loss: 9.4126
# Time : 12m 6s     | Epoch [1261/30000]	Train loss: 5.5738	 Vali loss: 9.4800
# Time : 12m 7s     | Epoch [1262/30000]	Train loss: 5.4944	 Vali loss: 9.3744
# Time : 12m 7s     | Epoch [1263/30000]	Train loss: 5.6337	 Vali loss: 9.0354
# Time : 12m 8s     | Epoch [1264/30000]	Train loss: 5.7632	 Vali loss: 8.3932
# Time : 12m 8s     | Epoch [1265/30000]	Train loss: 5.5118	 Vali loss: 8.3986
# Time : 12m 9s     | Epoch [1266/30000]	Train loss: 5.6961	 Vali loss: 9.5225
# Time : 12m 9s     | Epoch [1267/30000]	Train loss: 5.5067	 Vali loss: 8.6164
# Time : 12m 10s    | Epoch [1268/30000]	Train loss: 5.4992	 Vali loss: 9.8909
# Time : 12m 11s    | Epoch [1269/30000]	Train loss: 5.6834	 Vali loss: 9.5297
# Time : 12m 11s    | Epoch [1270/30000]	Train loss: 5.4328	 Vali loss: 9.0370
# Time : 12m 12s    | Epoch [1271/30000]	Train loss: 5.6265	 Vali loss: 8.8342
# Time : 12m 12s    | Epoch [1272/30000]	Train loss: 5.8629	 Vali loss: 9.1198
# Time : 12m 13s    | Epoch [1273/30000]	Train loss: 6.0323	 Vali loss: 8.5711
# Time : 12m 13s    | Epoch [1274/30000]	Train loss: 5.8630	 Vali loss: 9.8613
# Time : 12m 14s    | Epoch [1275/30000]	Train loss: 5.5935	 Vali loss: 9.2410
# ------------------Train Test------------------
# Now Epoch [1275/30000]
# Test MAE: 7.7105	 Test Std.: 9.3911	Test R2 score: 0.6418
# ----------------------------------------------
# Time : 12m 15s    | Epoch [1276/30000]	Train loss: 5.5703	 Vali loss: 9.7569
# Time : 12m 15s    | Epoch [1277/30000]	Train loss: 5.8895	 Vali loss: 10.6005
# Time : 12m 16s    | Epoch [1278/30000]	Train loss: 5.8143	 Vali loss: 9.9663
# Time : 12m 16s    | Epoch [1279/30000]	Train loss: 5.6963	 Vali loss: 9.4515
# Time : 12m 17s    | Epoch [1280/30000]	Train loss: 5.6720	 Vali loss: 9.3199
# Time : 12m 18s    | Epoch [1281/30000]	Train loss: 5.7428	 Vali loss: 9.7551
# Time : 12m 18s    | Epoch [1282/30000]	Train loss: 5.7323	 Vali loss: 10.4743
# Time : 12m 19s    | Epoch [1283/30000]	Train loss: 5.6712	 Vali loss: 9.5536
# Time : 12m 19s    | Epoch [1284/30000]	Train loss: 5.4994	 Vali loss: 10.3323
# Time : 12m 20s    | Epoch [1285/30000]	Train loss: 5.7207	 Vali loss: 9.0237
# Time : 12m 21s    | Epoch [1286/30000]	Train loss: 5.7369	 Vali loss: 8.9853
# Time : 12m 21s    | Epoch [1287/30000]	Train loss: 5.9135	 Vali loss: 9.9867
# Time : 12m 22s    | Epoch [1288/30000]	Train loss: 5.9718	 Vali loss: 8.8200
# Time : 12m 22s    | Epoch [1289/30000]	Train loss: 5.7052	 Vali loss: 8.6135
# Time : 12m 23s    | Epoch [1290/30000]	Train loss: 5.8334	 Vali loss: 8.7257
# Time : 12m 23s    | Epoch [1291/30000]	Train loss: 5.8447	 Vali loss: 9.2057
# Time : 12m 24s    | Epoch [1292/30000]	Train loss: 5.8423	 Vali loss: 10.9175
# Time : 12m 25s    | Epoch [1293/30000]	Train loss: 5.7394	 Vali loss: 10.4046
# Time : 12m 25s    | Epoch [1294/30000]	Train loss: 5.8601	 Vali loss: 9.6039
# Time : 12m 26s    | Epoch [1295/30000]	Train loss: 5.6966	 Vali loss: 10.8883
# Time : 12m 26s    | Epoch [1296/30000]	Train loss: 5.7068	 Vali loss: 9.2247
# Time : 12m 27s    | Epoch [1297/30000]	Train loss: 5.7746	 Vali loss: 9.4608
# Time : 12m 27s    | Epoch [1298/30000]	Train loss: 5.5846	 Vali loss: 9.4608
# Time : 12m 28s    | Epoch [1299/30000]	Train loss: 5.7258	 Vali loss: 10.0863
# Time : 12m 29s    | Epoch [1300/30000]	Train loss: 5.8276	 Vali loss: 9.2201
# ------------------Train Test------------------
# Now Epoch [1300/30000]
# Test MAE: 7.6091	 Test Std.: 8.9522	Test R2 score: 0.6566
# ----------------------------------------------
# Time : 12m 29s    | Epoch [1301/30000]	Train loss: 5.4242	 Vali loss: 9.5724
# Time : 12m 30s    | Epoch [1302/30000]	Train loss: 5.7840	 Vali loss: 9.6496
# Time : 12m 30s    | Epoch [1303/30000]	Train loss: 5.5450	 Vali loss: 9.8725
# Time : 12m 31s    | Epoch [1304/30000]	Train loss: 5.7217	 Vali loss: 9.2605
# Time : 12m 31s    | Epoch [1305/30000]	Train loss: 5.4249	 Vali loss: 8.8689
# Time : 12m 32s    | Epoch [1306/30000]	Train loss: 5.9374	 Vali loss: 10.3460
# Time : 12m 33s    | Epoch [1307/30000]	Train loss: 5.7159	 Vali loss: 10.7173
# Time : 12m 33s    | Epoch [1308/30000]	Train loss: 5.7778	 Vali loss: 10.6164
# Time : 12m 34s    | Epoch [1309/30000]	Train loss: 5.6789	 Vali loss: 9.8193
# Time : 12m 34s    | Epoch [1310/30000]	Train loss: 5.7795	 Vali loss: 9.9520
# Time : 12m 35s    | Epoch [1311/30000]	Train loss: 5.5910	 Vali loss: 9.9684
# Time : 12m 35s    | Epoch [1312/30000]	Train loss: 5.4832	 Vali loss: 10.9026
# Time : 12m 36s    | Epoch [1313/30000]	Train loss: 5.5495	 Vali loss: 11.2336
# Time : 12m 37s    | Epoch [1314/30000]	Train loss: 5.6613	 Vali loss: 9.3308
# Time : 12m 37s    | Epoch [1315/30000]	Train loss: 5.6598	 Vali loss: 9.2680
# Time : 12m 38s    | Epoch [1316/30000]	Train loss: 5.7374	 Vali loss: 9.2094
# Time : 12m 38s    | Epoch [1317/30000]	Train loss: 5.6314	 Vali loss: 9.8915
# Time : 12m 39s    | Epoch [1318/30000]	Train loss: 5.6686	 Vali loss: 10.9764
# Time : 12m 39s    | Epoch [1319/30000]	Train loss: 6.0239	 Vali loss: 8.3479
# Time : 12m 40s    | Epoch [1320/30000]	Train loss: 5.4293	 Vali loss: 9.4404
# Time : 12m 41s    | Epoch [1321/30000]	Train loss: 5.7342	 Vali loss: 9.3276
# Time : 12m 41s    | Epoch [1322/30000]	Train loss: 5.6369	 Vali loss: 8.1557
# Time : 12m 42s    | Epoch [1323/30000]	Train loss: 5.8788	 Vali loss: 9.4217
# Time : 12m 42s    | Epoch [1324/30000]	Train loss: 5.6815	 Vali loss: 10.0379
# Time : 12m 43s    | Epoch [1325/30000]	Train loss: 5.7053	 Vali loss: 8.9616
# ------------------Train Test------------------
# Now Epoch [1325/30000]
# Test MAE: 7.4373	 Test Std.: 9.1689	Test R2 score: 0.6573
# ----------------------------------------------
# Time : 12m 44s    | Epoch [1326/30000]	Train loss: 5.6635	 Vali loss: 8.8068
# Time : 12m 44s    | Epoch [1327/30000]	Train loss: 5.6147	 Vali loss: 8.2629
# Time : 12m 45s    | Epoch [1328/30000]	Train loss: 5.7077	 Vali loss: 10.7591
# Time : 12m 45s    | Epoch [1329/30000]	Train loss: 5.7499	 Vali loss: 9.8989
# Time : 12m 46s    | Epoch [1330/30000]	Train loss: 5.6652	 Vali loss: 10.5389
# Time : 12m 46s    | Epoch [1331/30000]	Train loss: 5.7487	 Vali loss: 9.8416
# Time : 12m 47s    | Epoch [1332/30000]	Train loss: 5.6890	 Vali loss: 9.3317
# Time : 12m 48s    | Epoch [1333/30000]	Train loss: 5.5742	 Vali loss: 10.0742
# Time : 12m 48s    | Epoch [1334/30000]	Train loss: 5.6074	 Vali loss: 9.6736
# Time : 12m 49s    | Epoch [1335/30000]	Train loss: 5.5000	 Vali loss: 9.5533
# Time : 12m 49s    | Epoch [1336/30000]	Train loss: 5.5224	 Vali loss: 9.6920
# Time : 12m 50s    | Epoch [1337/30000]	Train loss: 5.6398	 Vali loss: 8.4469
# Time : 12m 50s    | Epoch [1338/30000]	Train loss: 5.7294	 Vali loss: 9.0267
# Time : 12m 51s    | Epoch [1339/30000]	Train loss: 5.5461	 Vali loss: 9.2546
# Time : 12m 52s    | Epoch [1340/30000]	Train loss: 5.5118	 Vali loss: 10.8089
# Time : 12m 52s    | Epoch [1341/30000]	Train loss: 5.6634	 Vali loss: 10.4384
# Time : 12m 53s    | Epoch [1342/30000]	Train loss: 5.6128	 Vali loss: 9.3533
# Time : 12m 53s    | Epoch [1343/30000]	Train loss: 5.5783	 Vali loss: 9.2692
# Time : 12m 54s    | Epoch [1344/30000]	Train loss: 5.7090	 Vali loss: 9.7943
# Time : 12m 54s    | Epoch [1345/30000]	Train loss: 5.4508	 Vali loss: 10.0555
# Time : 12m 55s    | Epoch [1346/30000]	Train loss: 5.7550	 Vali loss: 9.5520
# Time : 12m 56s    | Epoch [1347/30000]	Train loss: 5.8854	 Vali loss: 8.3655
# Time : 12m 56s    | Epoch [1348/30000]	Train loss: 5.7225	 Vali loss: 9.3689
# Time : 12m 57s    | Epoch [1349/30000]	Train loss: 5.9168	 Vali loss: 9.5410
# Time : 12m 57s    | Epoch [1350/30000]	Train loss: 5.5640	 Vali loss: 9.8699
# ------------------Train Test------------------
# Now Epoch [1350/30000]
# Test MAE: 8.3028	 Test Std.: 9.6167	Test R2 score: 0.5868
# ----------------------------------------------
# Time : 12m 58s    | Epoch [1351/30000]	Train loss: 5.9557	 Vali loss: 9.0363
# Time : 12m 58s    | Epoch [1352/30000]	Train loss: 5.4179	 Vali loss: 9.3782
# Time : 12m 59s    | Epoch [1353/30000]	Train loss: 5.4808	 Vali loss: 10.5431
# Time : 13m 0s     | Epoch [1354/30000]	Train loss: 5.4045	 Vali loss: 10.4170
# Time : 13m 0s     | Epoch [1355/30000]	Train loss: 5.7113	 Vali loss: 9.2498
# Time : 13m 1s     | Epoch [1356/30000]	Train loss: 5.4587	 Vali loss: 9.7805
# Time : 13m 1s     | Epoch [1357/30000]	Train loss: 5.6116	 Vali loss: 8.8436
# Time : 13m 2s     | Epoch [1358/30000]	Train loss: 5.6850	 Vali loss: 10.6492
# Time : 13m 2s     | Epoch [1359/30000]	Train loss: 5.7290	 Vali loss: 10.2683
# Time : 13m 3s     | Epoch [1360/30000]	Train loss: 5.5433	 Vali loss: 9.2882
# Time : 13m 4s     | Epoch [1361/30000]	Train loss: 5.4425	 Vali loss: 10.2224
# Time : 13m 4s     | Epoch [1362/30000]	Train loss: 5.6865	 Vali loss: 9.1652
# Time : 13m 5s     | Epoch [1363/30000]	Train loss: 5.5435	 Vali loss: 9.3673
# Time : 13m 5s     | Epoch [1364/30000]	Train loss: 5.5450	 Vali loss: 8.7026
# Time : 13m 6s     | Epoch [1365/30000]	Train loss: 5.6889	 Vali loss: 8.8198
# Time : 13m 6s     | Epoch [1366/30000]	Train loss: 5.6343	 Vali loss: 9.2500
# Time : 13m 7s     | Epoch [1367/30000]	Train loss: 5.6119	 Vali loss: 8.5966
# Time : 13m 8s     | Epoch [1368/30000]	Train loss: 5.6133	 Vali loss: 9.6444
# Time : 13m 8s     | Epoch [1369/30000]	Train loss: 5.5387	 Vali loss: 8.4311
# Time : 13m 9s     | Epoch [1370/30000]	Train loss: 5.7353	 Vali loss: 9.5520
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-2d8a697d62a0> in <module>()
#       3 start = time.time()
#       4 for i in range(0, args.n_epochs):
# ----> 5     train_loss = train(model, optimizer, train_loader, criterion)
#       6     vali_loss = validate(model, validate_loader, criterion)
#       7     print('Time : {:10s} | Epoch [{}/{}]\tTrain loss: {:.4f}\t Vali loss: {:0.4f}'.format(timeSince(start),i + 1, args.n_epochs, train_loss, vali_loss))
#
# <ipython-input-7-a1499098939c> in train(model, optimizer, data_loader, criterion)
#       9         optimizer.zero_grad()
#      10         loss.backward()
# ---> 11         optimizer.step()
#      12
#      13         train_loss += loss.item()
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/adam.py in step(self, closure)
#     117                    group['lr'],
#     118                    group['weight_decay'],
# --> 119                    group['eps']
#     120                    )
#     121         return loss
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      96         step_size = lr / bias_correction1
#      97
# ---> 98         param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:

# %% [markdown]
# 잠정적으로 효과가 없음으로 판단, 모델 수정은 추후에 하기로 결론

# %% [markdown]
# # 5. Cross Validation
# ---

# %%
def crossValidation(data = None, n_splits = 5, random_state=400, args=None, savePath="./"):
    import os
    import csv 
    from sklearn.model_selection import KFold    
    kfold = KFold(n_splits=n_splits, random_state=random_state, shuffle=True)

    valid_mae = 0
    
    log_ = savePath + "/_Train_log.csv"
    evaluation_ = savePath + "/_evaluation_log.csv"

    if not os.path.exists(log_):
      with open(log_, mode='w') as f:
        myWriter = csv.writer(f)
        myWriter.writerow(["stage","epoch","loss"])

    if not os.path.exists(evaluation_):
      with open(evaluation_, mode='w') as f:
        myWriter = csv.writer(f)
        myWriter.writerow(["stage","epoch","MAE","Std","R2"])

    for stage, (train_index, validate_index) in enumerate(kfold.split(data)): #cross validation, k=5
        
        print("""

        --- now validation Round : {} ---""".format(stage+1), end="")

        valid_train_data=list()
        validate_data=list()
        
        for i in train_index:
            valid_train_data.append(data[i])
        for i in validate_index:  
            validate_data.append(data[i])

        # MAE 모니터링을 위한 Extract 
        valid_targets=np.array([x.y.item() for x in validate_data]).reshape(-1, 1)

        # KFold에 의해 나누어진 코드들을 학습에 사용하기 위해서 데이터 셋으로 변환 
        valid_train_loader = DataLoader(valid_train_data, batch_size=args.batch_size, shuffle=True)
        valid_loader = DataLoader(validate_data, batch_size=100)

        # 모델 초기화 
        model = EGCN(args).to(args.DEVICE)
        optimizer = torch.optim.Adam(model.parameters(), lr=args.init_lr, weight_decay=args.l2_coeff)
        criterion = torch.nn.L1Loss()

        stage_indicator = "Round : " + str(stage+1) + " | Epoch"
        for idx in tqdm(range(0, args.n_epochs), desc=stage_indicator): #각 cross validation 을 지정된 epoch으로 실행  
            train_loss = train(model, optimizer, valid_train_loader, criterion)


            with open(log_, mode='a') as f:  
              myWriter = csv.writer(f)
              myWriter.writerow([stage,idx+1,train_loss])

            if (idx+1) % 25 == 0 :
              preds = test(model, valid_loader)
              test_mae = np.mean(np.abs(valid_targets - preds))
              test_std = np.std(valid_targets - preds)
              r2 = r2_score(valid_targets, preds)

              with open(evaluation_, mode='a') as f:  
                myWriter = csv.writer(f)
                myWriter.writerow([stage, idx+1, test_mae, test_std, r2])
              # print()
              # print("------------------Train Test------------------")
              # print("Now Epoch [{}/{}]".format(i+1, args.n_epochs))
              # print('Test MAE: {:.4f}\t Test Std.: {:.4f}\tTest R2 score: {:.4f}'.format(test_mae,test_std, r2))
              # print("----------------------------------------------")
              

        preds = test(model, valid_loader)
        valid_targets=np.array([x.y.item() for x in validate_data]).reshape(-1, 1)
        tmp_mae = np.mean(np.abs(valid_targets - preds))
        print(i+1,' validation mae: ',tmp_mae)
        valid_mae = valid_mae+tmp_mae
    
    print('total mae:',valid_mae,' mean mae:',valid_mae/5)

# %%
crossValidation(data = train_data[:,1], n_splits=5, args=args, savePath = "/content/drive/MyDrive/0_한동생활/2020-2.5 겨울방학/2_GNN/data")
# Out:
# Round : 1 | Epoch:   0%|          | 0/30000 [00:00<?, ?it/s]
#         --- now validation Round : 1 ---
# Round : 1 | Epoch: 100%|██████████| 30000/30000 [3:57:26<00:00,  2.11it/s]
# 1170  validation mae:  7.034219863566946
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-00cb6a4e5e01> in <module>()
# ----> 1 crossValidation(data = train_data[:,1], n_splits=5, args=args, savePath = "/content/drive/MyDrive/0_한동생활/2020-2.5 겨울방학/2_GNN/data")
#
# <ipython-input-32-661aace306e7> in crossValidation(data, n_splits, random_state, args, savePath)
#      77         valid_mae = valid_mae+tmp_mae
#      78
# ---> 79         loss_slot.append(train_losses)
#      80         eval_slot.append(all_seq)
#      81
#
# NameError: name 'loss_slot' is not defined

# %%
from datetime import date, datetime, timezone, timedelta

exp_day = str(date.today())

KST = timezone(timedelta(hours=9))
time_record = datetime.now(KST)
_day = str(time_record)[:10]
_time = str(time_record.time())[:8]

print(exp_day)
print(datetime.now(KST))
print(_day)
print(_time)
# Out:
# 2021-02-15
# 2021-02-15 14:35:36.866411+09:00
# 2021-02-15
# 14:35:36

# %% [markdown]
# # 6. Visualization
# ---

# %%
all_seq = all_seq[1:]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotnine as gg 
sns.set_style("darkgrid", {"axes.facecolor": "gainsboro"})
df = pandas.DataFrame(all_seq, columns=("Epoch","MAE","Std.","R2_score"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-efc9e4aca3fd> in <module>()
#       4 import plotnine as gg
#       5 sns.set_style("darkgrid", {"axes.facecolor": "gainsboro"})
# ----> 6 df = pandas.DataFrame(all_seq, columns=("Epoch","MAE","Std.","R2_score"))
#
# NameError: name 'all_seq' is not defined

# %%
#  https://blog.naver.com/nife0719/221000580841
df = pd.DataFrame(all_seq, columns=("Epoch","MAE","Std.","R2_score"))

# ggplot(df[["Epoch","R2_Score"]], aes(x="Epoch")) + geom_density(alpha=.1)
score_df = df[["Epoch","R2_score"]]

score_graph = gg.ggplot(score_df, aes(sample="R2_score", x="Epoch", y="R2_score",ymin=0.8, ymax=1, fill="R2_score")) 
score_graph += gg.geom_point(size=2,color="dodgerblue", alpha=0.9)# + geom_qq(size=2,color="blue", alpha=0.9)
score_graph += gg.ggtitle("R2 score on training")
score_graph += gg.labs(x="Epoch", y="R2 score")

trend_graph = gg.ggplot(score_df, aes(x="Epoch",y="R2_score",ymin=0.8, ymax=1, fill="R2_score")) 
# trend_graph += geom_qq(size=2,color="dodgerblue", alpha=0.5) 
# trend_graph += geom_qq_line(size=1.2,color="blue",alpha=0.8) 
# method ['lm', 'ols', 'wls', 'rlm', 'glm', 'gls', 'lowess', 'loess', 'mavg', 'gpr']
"""
'auto'       # Use loess if (n<1000), glm otherwise
            'lm', 'ols'  # Linear Model
            'wls'        # Weighted Linear Model
            'rlm'        # Robust Linear Model
            'glm'        # Generalized linear Model
            'gls'        # Generalized Least Squares
            'lowess'     # Locally Weighted Regression (simple)
            'loess'      # Locally Weighted Regression
            'mavg'       # Moving Average
            'gpr'        # Gaussian Process Regressor
"""
trend_graph += gg.geom_smooth(span=.3, method='gls') 
trend_graph += gg.geom_point(size=2, color="dodgerblue") 
trend_graph += gg.ggtitle("Tendency of R2 score")
trend_graph += gg.labs(x="Epoch", y="R2 score")
trend_graph += gg.ylim(0,1)

score_graph.draw()
trend_graph.draw()
# Out:
# /usr/local/lib/python3.6/dist-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# /usr/local/lib/python3.6/dist-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: ./trend_graph.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)

# %%
MAE_df = df[["MAE","Epoch"]]
MAE_df[" "] = "MAE"
MAE_df =MAE_df.rename(columns={"MAE":"value"})
Std_df = df[["Std.","Epoch"]]
Std_df[" "] = "Std."
Std_df =Std_df.rename(columns={"Std.":"value"})
value_df = pd.concat([MAE_df,Std_df], axis=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
# Test the trained GNN
preds = test(model, test_loader)
test_mae = np.mean(np.abs(test_targets - preds))
r2 = r2_score(test_targets, preds)
print('Test MAE: {:.4f}\tTest R2 score: {:.4f}'.format(test_mae, r2))
print("--------------HyperParameter Info--------------")
print("Batch : {}, init_lr : {}, l2_coeff : {}, epoch : {}".format(batch_size,init_lr,l2_coeff,n_epochs))
print("criterion : {}, hidden Channel : {}".format(criterion,256))
print("Feature Num. : {}".format(len(elem_feat_names)))
print("-----------------------------------------------")


plt.subplots(1,2,figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(all_seq[1:,0], all_seq[1:,1],label="MAE")
plt.plot(all_seq[1:,0], all_seq[1:,2], label="STD")
plt.ylim(1,10)
plt.title("MAE & Std.",size=15)
plt.legend()
plt.subplot(1,2,2)
# plt.plot(all_seq[1:,0], all_seq[1:,3], label="R2_score")
# plt.title("R2_Score on Training",size=15)
plt.plot(train_losses, label="train", linewidth=3, color="dodgerblue",alpha=0.8)
plt.plot(vali_losses, label="validation", linewidth=1,color="orangered",alpha=0.8)
plt.ylim(0,20)
plt.title("Train & Vaildation Loss",size=15)
plt.legend()

plt.show()
# Out:
# Test MAE: 3.2129	Test R2 score: 0.9042
# --------------HyperParameter Info--------------
# Batch : 32, init_lr : 0.0005, l2_coeff : 0.0, epoch : 5000
# criterion : L1Loss(), hidden Channel : 256
# Feature Num. : 12
# -----------------------------------------------

# %%
# Save prediction results
pred_results = list()
for i in range(0, preds.shape[0]):
    pred_results.append([test_smiles[i], test_targets[i].item(), preds[i].item()])
df = pandas.DataFrame(pred_results)
df.columns = ['smiles', 'true_y', 'pred_y']
# df.to_excel('EGCN_Default.xlsx', index=False)
